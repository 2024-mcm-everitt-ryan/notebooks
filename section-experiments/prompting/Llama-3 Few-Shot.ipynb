# %% [markdown]
# # Llama-3 Few-Shot Inference

# %%
#val_or_test_split = 'val'
val_or_test_split = 'test'

# %%
# !pip install -q transformers datasets sentencepiece accelerate evaluate tiktoken einops flash-attn

# %%
from datasets import load_dataset

hf_site_id = '2024-mcm-everitt-ryan'
dataset_id = f'{hf_site_id}/job-bias-synthetic-human-benchmark-v2'

dataset = load_dataset(dataset_id)
column_names = dataset['train'].column_names

text_col = 'text'
label_cols = [col for col in column_names if col.startswith('label_')]

labels = [label.replace("label_", "") for label in label_cols]

id2label = {idx: label for idx, label in enumerate(labels)}
label2id = {label: idx for idx, label in enumerate(labels)}

# Remove all columns apart from the two needed for multi-class classification
keep_columns = ['context_id', 'synthetic', 'verified', text_col] + label_cols
for split in ["train", "val", "test"]:
    dataset[split] = dataset[split].remove_columns(
        [col for col in dataset[split].column_names if col not in keep_columns])

# %% [markdown]
# # Get few-shot examples from Train set

# %%
def get_multiple_true_bias(bias_col):
    other_label_cols = [col for col in label_cols if col != bias_col]
#    multiple_bias_samples = dataset['train'].filter(lambda x: x[bias_col] == True and x['synthetic'] == False and any(x[other_label_col] == True for other_label_col in other_label_cols))
    multiple_bias_samples = dataset['train'].filter(lambda x: x[bias_col] == True and any(x[other_label_col] == True for other_label_col in other_label_cols))
    return multiple_bias_samples

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 200)
pd.set_option('display.expand_frame_repr', False)

print("Age and Other")
age_and_other = get_multiple_true_bias('label_age')
print(age_and_other.to_pandas().head(10))
print("Disability and Other")
disability_and_other = get_multiple_true_bias('label_disability')
print(disability_and_other.to_pandas().head(20))
print("Feminine and Other")
feminine_and_other = get_multiple_true_bias('label_feminine')
print(feminine_and_other.to_pandas().head(10))
print("Masculine and Other")
masculine_and_other = get_multiple_true_bias('label_masculine')
print(masculine_and_other.to_pandas().head(15))
print("Racial and Other")
racial_and_other = get_multiple_true_bias('label_racial')
print(racial_and_other.to_pandas().head(10))
print("General and Other")
general_and_other = get_multiple_true_bias('label_general')
print(general_and_other.to_pandas().head(10))

no_bias = dataset['train'].filter(lambda x: x['label_neutral'] == True and x['synthetic'] == False and x['verified'] == True)
print("No Bias")
print(no_bias.to_pandas().head(10))
# Out:
# Age and Other
#    label_age  label_disability  label_feminine  label_general  label_masculine  label_neutral  label_racial  label_sexuality  verified  synthetic                                                                                                                                                                                                     text
# 0       True             False           False          False             True          False         False            False      True      False  10-15 years web and desktop application development work experience.\n\n- Experienced with JSON, Angular, JQuery, AJAX, XML, and REST web services.\n- Experienced with MongoDB, MySQL, and PostgreS...
# 1       True             False           False          False            False          False          True            False      True      False  5 years of Materials Planning experience. Worked with Global MNC.\n\nAbout Our Client\nOur client is a global manufacturer of home appliances.\n\nJob Description\n- Handle activities related to th...
# 2       True              True           False           True             True          False         False            False      True      False  About the business\n\nLumber Punks Axe Throwing is more than an activity, it's a movement. We bring the Punk ethos to everything we do and make sure every guest who visits us leaves knowing why Lu...
# 3       True             False           False          False             True          False          True            False      True      False  Main responsibilities:\n- Develop new business category within the company: seeds and materials (fertilizers, pesticides) for vegetable growers in Estonia.\n- Maintain and expand current customer ...
# 4       True              True           False          False            False          False         False            False      True      False  About the business:\nCredo is a thriving and vibrant company delivering project solutions that enable retailers to execute change. Our customers are leading retailers, with national store networks...
# 5       True             False           False          False             True          False         False             True      True      False  .NET Senior Engineer\n\nDescription\n\nDXC Technology India is seeking great talent to join the Digital Design group. The Digital Design group works on the latest and emerging digital technologies...
# 6       True             False           False          False            False          False          True            False      True      False  HelloFresh is looking for a hungry mid-level copywriter (pun always intended). They'll join a team of talented, driven creatives who have a knack for problem-solving and a passion for storytelling...
# 7       True             False            True          False            False          False         False            False      True      False  10 years experience in developing and supporting the implementation of communication strategies, preferably for development projects. Capability and proven experience in developing communication m...
# 8       True              True           False          False             True          False         False            False      True      False  Sales Representative - Media and Internet\n\nJoin our award-winning sales and marketing team today! We offer incredible advancement opportunities to our top performers. If you are looking to move ...
# 9       True             False           False          False             True          False          True             True      True      False  3 Years experience in travel companies business as sales or KAM or success in a similar position. Professional English is required, Arabic and Russian very welcome. Direct Procurement and 3rd part...
# Disability and Other
#     label_age  label_disability  label_feminine  label_general  label_masculine  label_neutral  label_racial  label_sexuality  verified  synthetic                                                                                                                                                                                                     text
# 0       False              True           False          False             True          False         False            False      True      False  3 MONTH CONTRACT. IMMEDIATE START. RESIDENTIAL TO PORT HEDLAND.\n\nAbout the Role:\nMy client is seeking labourers to join their team for a civil project. For this role, you will need to be physic...
# 1        True              True           False           True             True          False         False            False      True      False  About the business\n\nLumber Punks Axe Throwing is more than an activity, it's a movement. We bring the Punk ethos to everything we do and make sure every guest who visits us leaves knowing why Lu...
# 2        True              True           False          False            False          False         False            False      True      False  About the business:\nCredo is a thriving and vibrant company delivering project solutions that enable retailers to execute change. Our customers are leading retailers, with national store networks...
# 3       False              True           False           True            False          False         False            False      True      False  There may be additional tracking required as a result of CDRCs review.\n\nKNOWLEDGE, SKILLS AND ABILITIES:\n- Strong knowledge of clinical research process, including working knowledge of all func...
# 4       False              True            True          False            False          False         False            False      True      False  $500 Sign-On Bonus Opportunity  \n- Day-1 Medical and Dental Benefits  \n- Quarterly Bonus Potential  \n- Generous Employee Discount  \n- Flexible Schedule Options  \n\nAbout  \nBloomingdales make...
# 5        True              True           False          False             True          False         False            False      True      False  Sales Representative - Media and Internet\n\nJoin our award-winning sales and marketing team today! We offer incredible advancement opportunities to our top performers. If you are looking to move ...
# 6       False              True           False          False             True          False         False            False      True      False  Seasons Funeral Homes are a recognised industry leader dedicated to making a difference in the lives of our families and the funeral profession. We have been established for over 30 years with bra...
# 7        True              True           False          False            False          False         False            False     False       True  Job Title: Marketing Coordinator\nCountry: Australia\nCompany: Ruiz, Pham and Wade\nRole Description:\n\nWe are seeking a Marketing Coordinator to join our dynamic team at Ruiz, Pham and Wade. As ...
# 8        True              True           False          False            False          False         False            False     False       True  Job Title: IT Support Specialist\n\nCompany Background:\nMann-Irwin is a leading technology firm in Oman, providing innovative solutions to a wide range of clients. With a strong focus on growth a...
# 9        True              True           False          False            False          False         False            False     False       True  Company: SenShop Co.\n\nRole: Retail Specialist\n\nCompany Background:\nSenShop Co. is a leading retail brand in Senegal dedicated to providing exceptional shopping experiences. We are committed t...
# 10       True              True           False           True            False          False         False            False     False       True  Company: Lesotho Community Champions\n\nRole: Community Service Manager\n\nCompany Background: Lesotho Community Champions is dedicated to improving the socio-economic conditions in local communit...
# 11       True              True           False          False            False          False         False            False     False       True  Company: GlobalTech Solutions  \nRole: Senior Director  \nLocation: United States  \n\nAbout Us:  \nGlobalTech Solutions is a leading technology firm with over 30 years of experience in providing ...
# 12       True              True           False          False            False          False         False             True     False       True  ### Company: Anderson, Smith and Gill\n### Role: Marketing Specialist\nLocation: London, UK  \nType: Full-Time  \nSalary: £30,000 - £40,000, based on experience and skills  \n\nAbout Us:  \nAnders...
# 13       True              True           False           True            False          False         False            False     False       True  Company: Sterling Safety Solutions  \nRole: Senior Safety Accident Investigator  \nLocation: United States  \n\nAbout Us:  \nSterling Safety Solutions is a leading provider of safety and risk mana...
# 14       True              True           False          False             True          False         False            False     False       True  Company: ProTech Dynamics  \nRole: Junior Software Developer  \nLocation: London, UK  \nSalary: We are committed to fair and equitable pay practices. The salary for this position ranges from £25,0...
# 15       True              True           False           True            False          False         False            False     False       True  <h1>Accounting Investment Analyst</h1>\n<p><strong>Company:</strong> FinTech Solutions</p>\n<p><strong>Location:</strong> New York, NY, USA</p>\n<p><strong>About Us:</strong> FinTech Solutions is ...
# 16       True              True           False          False            False          False         False             True     False       True  Company: Garcia, Young and Williams  \nRole: Senior Marketing Strategist  \nCountry: United States  \n\nCompany Background:  \nGarcia, Young and Williams is a leading marketing and branding consul...
# 17       True              True           False          False            False          False          True            False     False       True  Company: Acosta-Harrell  \nCountry: United States  \nRole: Marketing Coordinator  \n\nCompany Background:  \nAcosta-Harrell is a forward-thinking marketing agency that emphasizes innovative soluti...
# 18       True              True           False          False            False          False          True            False     False       True  <company>Wolfe, Cooper and Harrison</company> is a leading organization dedicated to improving mental health education in schools across Iran. We are currently seeking a dynamic and ambitious indi...
# 19       True              True            True          False            False          False         False            False     False       True  Company Background: \nGlobal Solutions Inc. is a leading consultancy firm based in New York, USA, dedicated to providing comprehensive business strategies and services to an array of clients world...
# Feminine and Other
#    label_age  label_disability  label_feminine  label_general  label_masculine  label_neutral  label_racial  label_sexuality  verified  synthetic                                                                                                                                                                                                     text
# 0      False             False            True          False            False          False         False             True      True      False  Summary\n\nPomellato is the first global luxury Italian fashion fine jeweler, unconventional, colourful. Established in Milan in 1967, Pomellato stands out on the international scene for its uniqu...
# 1      False             False            True           True            False          False         False            False      True      False  About Ryman Retirement Villages\n\nRyman Healthcare's Jane Winstone Retirement Village has a strong family and community focus. With a welcoming atmosphere, our village is filled with people who e...
# 2      False              True            True          False            False          False         False            False      True      False  $500 Sign-On Bonus Opportunity  \n- Day-1 Medical and Dental Benefits  \n- Quarterly Bonus Potential  \n- Generous Employee Discount  \n- Flexible Schedule Options  \n\nAbout  \nBloomingdales make...
# 3       True             False            True          False            False          False         False            False      True      False  10 years experience in developing and supporting the implementation of communication strategies, preferably for development projects. Capability and proven experience in developing communication m...
# 4      False             False            True          False            False          False          True             True      True      False  20,000 to 25,000 SAR basic salary. Bonus (tax-free). Annual flights to home country. Medical insurance.\n\nOur partner is an exciting operator who is bringing world-class facilities to the Saudi A...
# 5       True             False            True          False            False          False         False            False     False       True  <h1>Senior Marketing Manager at Reid, Roberson and Garcia</h1>\n\n<p>Reid, Roberson and Garcia is a respectable marketing firm renowned for its innovative strategies and client-centric approaches....
# 6       True             False            True          False            False          False         False            False     False       True  Company: Davis-Mack\nLocation: Iraq\n\nPosition: Senior Historical Affairs Consultant\n\nCompany Overview:\nDavis-Mack is a reputed consultancy firm specializing in historical research and preserv...
# 7       True             False            True          False            False          False          True            False     False       True  <h2>About Us</h2>\nAtlantic Engineering Solutions is a leader in innovative engineering projects across the United States Minor Outlying Islands. Our mission is to push the boundaries of technolog...
# 8       True             False            True          False            False          False          True            False     False       True  Company: Crawford-Lowe  \nLocation: Canada  \nRole: Telephone Operator  \n\nCompany Background:  \nCrawford-Lowe is a renowned telecommunications company committed to fostering an inclusive workpl...
# 9       True             False            True          False            False          False          True            False     False       True  <h1>Job Posting: Furniture Finisher at Ramos and Sons</h1>\n\n<h2>Company Overview:</h2>\n<p>Ramos and Sons has been a leading name in the furniture industry in Guyana for over 50 years. We are co...
# Masculine and Other
#     label_age  label_disability  label_feminine  label_general  label_masculine  label_neutral  label_racial  label_sexuality  verified  synthetic                                                                                                                                                                                                     text
# 0       False              True           False          False             True          False         False            False      True      False  3 MONTH CONTRACT. IMMEDIATE START. RESIDENTIAL TO PORT HEDLAND.\n\nAbout the Role:\nMy client is seeking labourers to join their team for a civil project. For this role, you will need to be physic...
# 1        True             False           False          False             True          False         False            False      True      False  10-15 years web and desktop application development work experience.\n\n- Experienced with JSON, Angular, JQuery, AJAX, XML, and REST web services.\n- Experienced with MongoDB, MySQL, and PostgreS...
# 2        True              True           False           True             True          False         False            False      True      False  About the business\n\nLumber Punks Axe Throwing is more than an activity, it's a movement. We bring the Punk ethos to everything we do and make sure every guest who visits us leaves knowing why Lu...
# 3        True             False           False          False             True          False          True            False      True      False  Main responsibilities:\n- Develop new business category within the company: seeds and materials (fertilizers, pesticides) for vegetable growers in Estonia.\n- Maintain and expand current customer ...
# 4       False             False           False           True             True          False         False            False      True      False  US$ 128.3 Trillion, that is the size of the Global Bond Market. And if you are interested in exploring a career and becoming an expert in Fixed Income Analysis, keep reading!\n\nIf you are keen to...
# 5        True             False           False          False             True          False         False             True      True      False  .NET Senior Engineer\n\nDescription\n\nDXC Technology India is seeking great talent to join the Digital Design group. The Digital Design group works on the latest and emerging digital technologies...
# 6       False             False           False          False             True          False          True            False      True      False  Native German speaker, fluent in English. Some Dutch is nice :). Commercially strong and a strong networker. Able to work independently with an entrepreneurial mindset. Your strategic thinking and...
# 7        True              True           False          False             True          False         False            False      True      False  Sales Representative - Media and Internet\n\nJoin our award-winning sales and marketing team today! We offer incredible advancement opportunities to our top performers. If you are looking to move ...
# 8        True             False           False          False             True          False          True             True      True      False  3 Years experience in travel companies business as sales or KAM or success in a similar position. Professional English is required, Arabic and Russian very welcome. Direct Procurement and 3rd part...
# 9       False              True           False          False             True          False         False            False      True      False  Seasons Funeral Homes are a recognised industry leader dedicated to making a difference in the lives of our families and the funeral profession. We have been established for over 30 years with bra...
# 10       True             False           False           True             True          False         False            False     False       True  Job Title: Sewing Machine Operator\nCompany: Prestige Fashion Co.\nLocation: Toronto, Canada\n\nAbout Us: Prestige Fashion Co. is a leading fashion brand that values traditional craftsmanship and ...
# 11       True             False           False          False             True          False         False            False     False       True  Company: Taylor-Sanders\n\nRole: GIS Analyst\n\nLocation: [City, Country]\n\nCompany Background:\nTaylor-Sanders is a leading geospatial and remote sensing company specializing in providing cuttin...
# 12       True             False           False           True             True          False         False            False     False       True  Company: Herrera, Diaz and Valdez\n\nRole: Drywall Installer\n\nCompany Background:\nHerrera, Diaz and Valdez have been leaders in the construction industry for over 25 years. We pride ourselves o...
# 13       True             False           False          False             True          False         False            False     False       True  #### Company: HealthGuard Lesotho\n\nPosition: Senior Public Health Inspector\n\nJob Type: Full-time\n\nCompany Background:\nHealthGuard Lesotho is a leading organization dedicated to enhancing pu...
# 14       True             False           False          False             True          False         False             True     False       True  <h1>Wellness Advocate Supervisor - Jackson-Norton, Korea</h1>\n<p><strong>Company Background:</strong> Jackson-Norton is a cutting-edge wellness company dedicated to promoting health and wellness ...
# Racial and Other
#    label_age  label_disability  label_feminine  label_general  label_masculine  label_neutral  label_racial  label_sexuality  verified  synthetic                                                                                                                                                                                                     text
# 0       True             False           False          False            False          False          True            False      True      False  5 years of Materials Planning experience. Worked with Global MNC.\n\nAbout Our Client\nOur client is a global manufacturer of home appliances.\n\nJob Description\n- Handle activities related to th...
# 1      False             False           False           True            False          False          True            False      True      False  You will be a pro-active self-starter with a naturally engaging demeanor and confidence in communicating with clients at senior levels. \n\nWe are looking for a native Spanish and/or Portuguese sp...
# 2       True             False           False          False             True          False          True            False      True      False  Main responsibilities:\n- Develop new business category within the company: seeds and materials (fertilizers, pesticides) for vegetable growers in Estonia.\n- Maintain and expand current customer ...
# 3       True             False           False          False            False          False          True            False      True      False  HelloFresh is looking for a hungry mid-level copywriter (pun always intended). They'll join a team of talented, driven creatives who have a knack for problem-solving and a passion for storytelling...
# 4      False             False           False          False             True          False          True            False      True      False  Native German speaker, fluent in English. Some Dutch is nice :). Commercially strong and a strong networker. Able to work independently with an entrepreneurial mindset. Your strategic thinking and...
# 5      False             False            True          False            False          False          True             True      True      False  20,000 to 25,000 SAR basic salary. Bonus (tax-free). Annual flights to home country. Medical insurance.\n\nOur partner is an exciting operator who is bringing world-class facilities to the Saudi A...
# 6       True             False           False          False             True          False          True             True      True      False  3 Years experience in travel companies business as sales or KAM or success in a similar position. Professional English is required, Arabic and Russian very welcome. Direct Procurement and 3rd part...
# 7       True             False           False           True            False          False          True            False     False       True  Company: Baltik Ventures\nRole: Marketing Specialist\n\nWe are a fast-paced and innovative marketing firm looking for a go-getter to join our team. If you're a team player with a degree from a rep...
# 8       True             False           False          False            False          False          True            False     False       True  Job Title: Marketing Coordinator\nLocation: Sydney, Australia\nCompany: Moore, Lane and Stephens\n\nAre you a team player who shares our values and cultural background? We're a close-knit team loo...
# 9       True             False           False          False            False          False          True             True     False       True  Job Title: Unix System Administrator\nCompany: Dean Ltd\nLocation: Malta\n\nAbout Us:\nDean Ltd is a leading technology company based in Malta, providing innovative solutions to businesses across ...
# General and Other
#    label_age  label_disability  label_feminine  label_general  label_masculine  label_neutral  label_racial  label_sexuality  verified  synthetic                                                                                                                                                                                                     text
# 0      False             False           False           True            False          False          True            False      True      False  You will be a pro-active self-starter with a naturally engaging demeanor and confidence in communicating with clients at senior levels. \n\nWe are looking for a native Spanish and/or Portuguese sp...
# 1       True              True           False           True             True          False         False            False      True      False  About the business\n\nLumber Punks Axe Throwing is more than an activity, it's a movement. We bring the Punk ethos to everything we do and make sure every guest who visits us leaves knowing why Lu...
# 2      False             False           False           True             True          False         False            False      True      False  US$ 128.3 Trillion, that is the size of the Global Bond Market. And if you are interested in exploring a career and becoming an expert in Fixed Income Analysis, keep reading!\n\nIf you are keen to...
# 3      False             False            True           True            False          False         False            False      True      False  About Ryman Retirement Villages\n\nRyman Healthcare's Jane Winstone Retirement Village has a strong family and community focus. With a welcoming atmosphere, our village is filled with people who e...
# 4      False              True           False           True            False          False         False            False      True      False  There may be additional tracking required as a result of CDRCs review.\n\nKNOWLEDGE, SKILLS AND ABILITIES:\n- Strong knowledge of clinical research process, including working knowledge of all func...
# 5       True             False           False           True            False          False         False            False     False       True  Country: United States\n\nCompany: Davis, Grant and Bell\n\nRole: Senior Financial Analyst\n\nAbout Us:\nDavis, Grant and Bell is a prestigious financial institution committed to delivering except...
# 6       True             False           False           True            False          False         False             True     False       True  Country: United States\n\nCompany: Ramos Inc\n\nJob Title: Triage Supervisor\n\nAbout Us:\nRamos Inc is a cutting-edge healthcare provider dedicated to delivering exceptional patient care. Our tea...
# 7       True             False           False           True            False          False          True            False     False       True  Company: Baltik Ventures\nRole: Marketing Specialist\n\nWe are a fast-paced and innovative marketing firm looking for a go-getter to join our team. If you're a team player with a degree from a rep...
# 8       True             False           False           True            False          False         False             True     False       True  Country: Australia\nCompany: Bloomfield Consulting\nRole: Senior Strategy Advisor\n\nAbout Us:\nBloomfield Consulting is a leading management consultancy firm that values diversity and inclusivity...
# 9       True             False           False           True            False          False         False            False     False       True  Job Title: Detective\nCompany: Ace Investigations Inc.\nLocation: Melbourne, Australia\n\nWe're a leading private investigation firm in Melbourne, seeking a highly motivated and driven detective t...
# No Bias
#    label_age  label_disability  label_feminine  label_general  label_masculine  label_neutral  label_racial  label_sexuality  verified  synthetic                                                                                                                                                                                                     text
# 0      False             False           False          False            False           True         False            False      True      False  5-7 years of relevant work experience.  \nExcellent verbal and written communication skills.  \nOutgoing and proactive personality.  \n\nIdeally, you also have:  \n- Good knowledge of how accounti...
# 1      False             False           False          False            False           True         False            False      True      False  Experienced Heavy Rigid Drivers\n\nABOUT THE CLIENT\nAction Workforce has partnered up with a very reputable company based in South Brisbane. This company is well known and prides itself on a grea...
# 2      False             False           False          False            False           True         False            False      True      False  Job Description:  \nIdentify inherent hazards to a process or facility to achieve a managed level of risk in operations and design. A key priority is the identification of potential LOC events and...
# 3      False             False           False          False            False           True         False            False      True      False  Description\n\nThe Forcepoint Security Labs team is looking for a talented security researcher to join our growing front-line team. This is the think-tank research group behind Forcepoint. You wil...
# 4      False             False           False          False            False           True         False            False      True      False  Description\n\nAre you a Mechanic looking for a change in pace? From major mill overhauls to conveying equipment of all kinds, this position has it all. You will perform preventative maintenance, ...
# 5      False             False           False          False            False           True         False            False      True      False  Good old kiwi ingenuity, a great team culture, and a relentless commitment to preserve New Zealand's natural beauty and resources, EnviroNZ ensure we produce the best possible outcomes for both ou...
# 6      False             False           False          False            False           True         False            False      True      False  Description:\n\nWant to join an AMAZING organization with a mission of building girls of COURAGE, CONFIDENCE, and CHARACTER who make the world a better place? Girl Scouts offers the best leadershi...
# 7      False             False           False          False            False           True         False            False      True      False  - 8-10 years of clinical experience working in a hospital, managed care environment, or medical office required.\n- Case Management in US IPMI environment preferred.\n- Case Management certificati...
# 8      False             False           False          False            False           True         False            False      True      False  Job Description\n\nPosting Date: Sep 21, 2021  \nJob Number: 21106112  \nJob Category: Housekeeping & Laundry  \nLocation: Four Points by Sheraton Desaru, Jalan Kempas 2, Bandar Penawar, Johor, Ma...
# 9      False             False           False          False            False           True         False            False      True      False  Description\n\nDo you want to work with one of Canada's top companies represented by an award-winning staffing agency? Look no further and join the Spirit circle today! Our client is looking for G...

# %%
def get_examples():
    examples = []

    text = general_and_other[1]['text']
    label = 'age, disability, masculine, general'
    examples.append({'answer':label, 'job_description':text})

    text = racial_and_other[9]['text']
    label = 'age, racial, sexuality'
    examples.append({'answer':label, 'job_description':text})

    text = no_bias[0]['text']
    label = 'neutral'
    examples.append({'answer':label, 'job_description':text})

    text = no_bias[1]['text']
    label = 'neutral'
    examples.append({'answer':label, 'job_description':text})

    return examples

examples = get_examples()

# %% [markdown]
# # Prompt Formatting & Data preprocessing

# %%
system = "You are an analyst of job postings. Your task is to detect implicit bias, if present.\n"
instruction = "Analyse the job posting for implicit bias. The bias categories are age, disability, feminine, masculine, racial, sexuality, general.  Return the appropriate label only when absolutely sure that the particular bias category is present in the text.\n"
closing_instruction = "Does the job posting contain any implicit bias? Please respond in the format of 'Labels: <labels>' where the possible labels are zero or more from the choices of age, disability, feminine, masculine, racial, sexuality, general. If no bias is detected please return 'Labels: neutral'. No further explanation is required."

def construct_prompt_few_shot (query_job_description):
#    messages = [{"role": "system", "content": system}]
    messages = []
    for i, ex in enumerate(examples):
        job = ex['job_description']
        answer = ex['answer']

        evidence = f"Job Posting: \n {job} \n ===END=== \n"
        if i == 0:
#            content = system + instruction + evidence + closing_instruction
            content = instruction + evidence + closing_instruction
        else:
            content = evidence + closing_instruction

        messages.append({"role": "user", "content": content})
        messages.append({"role": "assistant", "content": "Labels: " + answer})

    evidence = f"Job Posting: \n {query_job_description} \n ===END=== \n"
    content = evidence + closing_instruction
    messages.append({"role": "user", "content": content})
    return messages

# %%
# Note this is different to previous notebooks in that the chat template is NOT applied.
def get_formatted_prompt(job_description):
    msgs = construct_prompt_few_shot(job_description)
    return msgs

# %%
import numpy as np

def preprocess_data(sample):
#    print(sample)
    # take a batch of texts
    text = sample[text_col]
    sample['prompt'] = list(map(get_formatted_prompt, sample[text_col]))
    # add labels
    labels_batch = {k: sample[k] for k in sample.keys() if k in label_cols}
    # create numpy array of shape (batch_size, num_labels)
    labels_matrix = np.zeros((len(text), len(label_cols)), dtype=int)
    # fill numpy array
    for idx, label in enumerate(label_cols):
        labels_matrix[:, idx] = labels_batch[label]

    sample["labels"] = labels_matrix.tolist()
    return sample

# Preprocess the dataset
processed_dataset = dataset.map(preprocess_data, batched=True, remove_columns=[col for col in dataset['train'].column_names if col not in ['prompt','labels']])

# %% [markdown]
# # Label extraction

# %%
import re

def extract_labels(text):
    # Define the regular expression pattern to capture the needed parts
    pattern = r'\b[Ll]abels:\s*(?P<labels>[^\.]+)'

    # Search the text for matches
    match = re.search(pattern, text, re.DOTALL)

    if match:
        # Extract the 'answer' part and split it into a list of words
        answer_list = match.group('labels').split(', ')
        return answer_list
    else:
        return None

def responses_to_predictions(responses):
    #Extract labels
    label_set = set(labels) # Just for efficiency
    predictions = []
    not_parsed = []
    for i, res in enumerate(responses):
        for seq in res:
            predicted = np.zeros((len(labels),), dtype=int)
            generated_text = seq['generated_text']

            words_list = extract_labels(generated_text)
            if words_list is not None:
                for idx, l in enumerate(labels):
                    if l in words_list:
                        predicted[idx] = 1

                predictions.append(predicted)
            else:
                not_parsed.append(i)
    return predictions, not_parsed

# %% [markdown]
# # Metrics & Result display

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, roc_auc_score, accuracy_score

# Define custom metric function
def compute_metrics(y_pred, y_true):
    accuracy = accuracy_score(y_true=y_true, y_pred=y_pred)
    f1_micro = f1_score(y_true=y_true, y_pred=y_pred, average='micro', zero_division=0.0)
    f1_macro = f1_score(y_true=y_true, y_pred=y_pred, average='macro', zero_division=0.0)
    f1_samples = f1_score(y_true=y_true, y_pred=y_pred, average='samples', zero_division=0.0)
    f1_weighted = f1_score(y_true=y_true, y_pred=y_pred, average='weighted', zero_division=0.0)

    precision_micro = precision_score(y_true=y_true, y_pred=y_pred, average='micro')
    recall_micro = recall_score(y_true=y_true, y_pred=y_pred, average='micro')
    roc_auc_micro = roc_auc_score(y_true=y_true, y_score=y_pred, average='micro')
    # return as dictionary
    metrics = {
        'accuracy': accuracy,
        f'f1_micro': f1_micro,
        f'f1_macro': f1_macro,
        f'f1_samples': f1_samples,
        f'f1_weighted': f1_weighted,
        f'precision_micro': precision_micro,
        f'recall_micro': recall_micro,
        f'roc_auc_micro': roc_auc_micro}
    return metrics

# Function to calculate true positives, false positives, true negatives, and false negatives
def calculate_counts(true_labels, predicted_labels):
    tp = np.sum((true_labels == 1) & (predicted_labels == 1), axis=0)
    fp = np.sum((true_labels == 0) & (predicted_labels == 1), axis=0)
    tn = np.sum((true_labels == 0) & (predicted_labels == 0), axis=0)
    fn = np.sum((true_labels == 1) & (predicted_labels == 0), axis=0)
    return tp, fp, tn, fn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def print_metrics(metrics):
    print("Evaluation Metrics:")
    print("===================")
    for metric, value in metrics.items():
        print(f"{metric.replace('_', ' ').capitalize():<20}: {value:.4f}")

def heatmap_TP_FP_TN_FN(tp, fp, tn, fn):
    data = {
        'True Positive': tp,
        'False Positive': fp,
        'True Negative': tn,
        'False Negative': fn
    }

    df = pd.DataFrame(data, index=labels)

    # Plot the data using seaborn
    plt.figure(figsize=(12, 6))
    sns.heatmap(df.T, annot=True, cmap='Blues', fmt='d', linewidths=.5)
    plt.title('Multi-Label Confusion Matrix Breakdown by Class')
    plt.xlabel('Labels')
    plt.ylabel('Counts')
    plt.show()

# %% [markdown]
# # Model, Tokenizer & Pipeline

# %%
# Load the model and tokenizer
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_name = "meta-llama/Meta-Llama-3-8B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name, padding_side='left', add_eos_token=True, add_bos_token=True)
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype="auto", trust_remote_code=True)

model.half() #this is needed if GPU ram is less than approx 26gb

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm()
#         (post_attention_layernorm): LlamaRMSNorm()
#       )
#     )
#     (norm): LlamaRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
# )

# %%
from transformers import pipeline
import torch

pipeline = pipeline("text-generation", model=model, tokenizer=tokenizer, torch_dtype=torch.float16, device_map=device)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %% [markdown]
# # Run Inference - Validation or Test

# %%
from sklearn.metrics import classification_report
from transformers.utils import logging

# Uncomment to test a subset
#num_tests=10
#data_to_test = processed_dataset[val_or_test_split].select(range(num_tests))
data_to_test = processed_dataset[val_or_test_split]

responses = pipeline(data_to_test['prompt'],
                     max_new_tokens=50,
                     pad_token_id=tokenizer.eos_token_id,
                     return_full_text=False,
                     do_sample=False
                     )

#Extract labels
predictions, not_parsed = responses_to_predictions(responses)

print(f"Num not parsed: {len(not_parsed)}")

#There still may be a few unparseable responses. Remove these from the ground truth labels
#In testing, this has always been zero, therefore results are valid.
truth_labels = data_to_test['labels']
filtered_truth_labels = [label for idx, label in enumerate(truth_labels) if idx not in not_parsed]

print_metrics(compute_metrics(predictions, filtered_truth_labels))

tp, fp, tn, fn = calculate_counts(np.array(filtered_truth_labels), np.array(predictions))
heatmap_TP_FP_TN_FN(tp, fp, tn, fn)

print(classification_report(filtered_truth_labels, predictions, target_names=labels, zero_division=0.0))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:540: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:545: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Num not parsed: 0
# Evaluation Metrics:
# ===================
# Accuracy            : 0.4058
# F1 micro            : 0.5220
# F1 macro            : 0.5381
# F1 samples          : 0.5421
# F1 weighted         : 0.5381
# Precision micro     : 0.4779
# Recall micro        : 0.5750
# Roc auc micro       : 0.7376
#               precision    recall  f1-score   support
#
#          age       0.65      0.50      0.56        80
#   disability       0.60      0.66      0.63        80
#     feminine       0.55      0.95      0.69        80
#      general       0.22      0.54      0.31        80
#    masculine       0.73      0.30      0.42        80
#      neutral       0.31      0.56      0.40        80
#       racial       0.76      0.70      0.73        80
#    sexuality       0.97      0.39      0.55        80
#
#    micro avg       0.48      0.57      0.52       640
#    macro avg       0.60      0.57      0.54       640
# weighted avg       0.60      0.57      0.54       640
#  samples avg       0.52      0.61      0.54       640
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#responses
