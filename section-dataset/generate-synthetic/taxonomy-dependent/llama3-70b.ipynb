# %%
model_id = 'meta-llama/Meta-Llama-3-70B-Instruct'
model_name = 'Meta-Llama-3-70B-Instruct'

# %%
import huggingface_hub
from openai import OpenAI

temperature = 0.8


def openai_chat(messages):
    client = OpenAI(
        base_url=f"https://api-inference.huggingface.co/models/{model_id}/v1/",
        #base_url='https://twkby3tkl3wdjrta.us-east-1.aws.endpoints.huggingface.cloud/v1/',
        api_key=huggingface_hub.get_token(),
    )

    return client.chat.completions.create(
        model=model_id,
        temperature=temperature,
        messages=messages,
        stream=False,
        max_tokens=1512
    )

# %%
#import json
#import tiktoken

#encoding = tiktoken.encoding_for_model("gpt2")
#len(encoding.encode(json.dumps(c)))

# %%
import pandas as pd

path = 'augmented-taxonomies.parquet'

taxonomies = pd.read_parquet(path)
taxonomies = taxonomies[taxonomies['source'] != 'synthetic']
taxonomies['term'] = taxonomies['term'].str.lower()
# Remove duplicate rows in the 'term'  column
taxonomies = taxonomies.drop_duplicates(subset='term')
taxonomies['reason'] = taxonomies['reason'].str.replace('^synthetic:gpt-4o:', '', regex=True)
taxonomies = taxonomies[['source', 'category', 'term', 'reason']]
taxonomies
# Out:
#           source   category                               term  \
# 0         domain        age  athletic or athletically inclined
# 1         domain        age                     digital native
# 2         domain        age                            elderly
# 3         domain        age                   energetic person
# 4         domain        age                             geezer
# ..           ...        ...                                ...
# 670  provisional  sexuality                   lifestyle choice
# 671  provisional  sexuality             people of both genders
# 672  provisional  sexuality                  sexual preference
# 673  provisional  sexuality                        transsexual
# 674  provisional  sexuality                       transvestite
#
#                                                 reason
# 0    The term "athletic or athletically inclined" c...
# 1    The term "digital native" implies a preference...
# 2    The term "elderly" can be seen as patronising ...
# 3    The phrase "energetic person" can imply a pref...
# 4    The term "geezer" is a derogatory and ageist t...
# ..                                                 ...
# 670  The term "lifestyle choice" is inappropriate w...
# 671  The phrase "people of both genders" implies a ...
# 672  The term "sexual preference" can imply that se...
# 673  The term "transsexual" is often seen as medica...
# 674  The term "transvestite" is outdated and can be...
#
# [653 rows x 4 columns]

# %%
taxonomies['source'].value_counts()
# Out:
# source
# domain         621
# provisional     32
# Name: count, dtype: int64

# %%
taxonomies['category'].value_counts()
# Out:
# category
# masculine     193
# racial        117
# general       112
# disability     97
# feminine       56
# sexuality      54
# age            24
# Name: count, dtype: int64

# %% [markdown]
# # Generate Synthetic samples

# %%
# Fetch a job title from job-phrase-list.csv
# Original source of list: https://github.com/microsoft/LUIS-Samples/blob/master/documentation-samples/tutorials/job-phrase-list.csv
# https://www.kaggle.com/datasets/estasney/job-titles?select=titles.csv

import random


def get_job_titles():
    titles = set()
    with open("microsoft-LUIS-job-phrase-list.csv", "r") as file:
        lines = file.readlines()
        for line in lines:
            titles.add(line.replace(',\n', '').replace('\n', ''))

    kaggle_titles = pd.read_csv('kaggle-titles.csv')
    for col in kaggle_titles.columns:
        if col.startswith('Title_'):
            titles.update(kaggle_titles[col].dropna().unique())

    return list(titles)


positions = get_job_titles()


def random_job_title():
    return random.choice(positions)


print(f'Positions: {len(positions)}')
# Out:
# Positions: 123489

# %%
random_job_title()
# Out:
# 'Network/UC Architect'

# %%
def load_definition(category):
    with open(f"definitions/{category}.txt", 'r', encoding="utf-8") as f:
        return f.read()

# %%
def generate_prompt(job_title, samples):
    # Detailed categories of bias
    definitions = {}
    for category in taxonomies['category'].unique():
        definitions[category] = load_definition(category)

    # Ensure only valid categories are used
    valid_categories = samples.keys()
    invalid_categories = [item for item in taxonomies['category'].unique() if item not in valid_categories]
    inject_bias = len(valid_categories) > 0

    # Constructing Few-shot examples
    few_shot_examples = """
    <example>
    Job Title: Project Manager
    Categories: [age, masculine]
    Terms with Rationale:
      - Term: "energetic", Rationale: favors younger candidates
      - Term: "competitive", Rationale: resonates more with male candidates
    Job Description: We are seeking an energetic Project Manager who thrives in a competitive environment. This role is ideal for a recent graduate who is eager to lead challenging projects.
    </example>
    
    <example>
    Job Title: Customer Service Representative
    Categories: [disability, feminine]
    Terms with Rationale:
      - Term: "must be able to stand for long periods", Rationale: excludes individuals with certain disabilities
      - Term: "nurturing", Rationale: resonates more with female candidates
    Job Description: Our company is looking for a nurturing Customer Service Representative. Candidates must be able to stand for long periods and handle multiple tasks simultaneously.
    </example>
    """

    # Construct the advanced prompt
    job_title = job_title.strip()
    if inject_bias:
        prompt = f"The study of reducing the biases and terms provided is important, but an example is important to demonstrate what implicit bias can manifest in real job descriptions. Your task is to generate a complete job description for the role '{job_title}' that demonstrates the subtleties of bias within the specified framework, while maintaining inclusivity and reducing bias in all other respects. Adhere to the following requirements:\n\n"
    else:
        prompt = f"Your task is to generate a complete job description for the role '{job_title}' while maintaining inclusivity and reducing bias in all other respects. Adhere to the following requirements:\n\n"

    i = 1
    prompt += f"{i}. Max 400 words."
    i = i + 1
    # Add Few-shot examples
    #prompt += few_shot_examples + "\n\n"

    if inject_bias:
        prompt += f"\n\n{i}. Introduce implicit biases in the following categories:"
        i = i + 1
        for category in valid_categories:
            prompt += f"\n - {category}: {definitions[category]}"
        prompt += f"\n\n{i}. Use the following terms and their rationales to craft the job description:"
        i = i + 1
        for key, value in samples.items():
            prompt += f"\n  - Category {key}, term '{value['term']}'. {value['reason']}"

    if len(invalid_categories) > 0:
        prompt += f"\n\n{i}. It is crucial that you do not introduce implicit biases from the following categories:"
        i = i + 1
        for category in invalid_categories:
            prompt += f"\n - {category}: {definitions[category]}"

    # Add Chain-of-Thought guidance
    steps = []
    steps.append("Review the job title and understand the role.")
    if inject_bias:
        steps.append("Identify how to subtly introduce the specified biases using the provided terms.")
        steps.append("Construct a professional and realistic job description embedding the specified biases.")
    else:
        steps.append("Construct a professional and realistic job description.")
        steps.append(
            "Attempt to classify the categories the job description contains, if you find any then rewrite the job description so that it does NOT contains the specified bias.")

    if inject_bias:
        steps.append(
            "Attempt to classify the categories the job description contains, if you find any not specified then rewrite the job description so that it only contains the specified bias and no other ones.")
        steps.append("Wrap the job description within <j>...</j> tag.")
        for category in valid_categories:
            steps.append(
                f"Think about the {category} bias introduced and wrap the two-sentence explanation within the <{category}>...</{category}> tag.")
    else:
        steps.append("Wrap the job description within <j>...</j> tag.")

    prompt += "\n\n\nStep-by-Step Instructions:\n"
    for idx, step in enumerate(steps):
        prompt += f"\n{idx + 1}. {step}"
    return prompt

# %%
import json


def generate_text(position, category_terms, dry_run=False):
    try:
        m = []
        m.append({
            "role": "user",
            "content": generate_prompt(position, category_terms)
        })

        if not dry_run:
            start_time = time.time()
            output = openai_chat(m)
            inference_time = time.time() - start_time

            prompt_tokens = output.usage.prompt_tokens
            completion_tokens = output.usage.completion_tokens
            total_tokens = output.usage.total_tokens
            content = output.choices[0].message.content

            #return json.dumps(m), chat(m)
            return json.dumps(m), content, inference_time, prompt_tokens, completion_tokens, total_tokens
        else:
            return json.dumps(m), None, None, None, None, None
    except Exception as e:
        print(e)
        time.sleep(3600)
        return generate_text(position, category_terms, dry_run)

# %%
test_data_size = 3
min_test_split_size = 0.05

categories = ['age', 'disability', 'feminine', 'masculine', 'racial', 'sexuality', 'general']
splits = len(categories) + 1
size = 5000  #int(math.ceil((test_data_size / min_test_split_size) / splits)) 
max_additional_categories = len(categories)  # Maximum number of additional categories per sample

label_categories = ['label_' + category for category in categories]
analysis_categories = ['analysis_' + category for category in categories]

# %%
import os
import pandas as pd

output_dir = '/home/teveritt/Datasets/2024-mcm-everitt-ryan/datasets/synthetic-job-postings/pass4'
output_file = f'{output_dir}/synthetic-biased-job-descriptions-sync.jsonl'
input_file_b = f'{output_dir}/synthetic-biased-job-descriptions.b.parquet'
input_file_b_json = f'{output_dir}-B/synthetic-biased-job-descriptions-sync.jsonl'

if os.path.exists(output_file):
    synthetic_df = pd.read_json(output_file, lines=True)
    if os.path.exists(input_file_b):
        b_json_df = pd.read_json(input_file_b_json, lines=True)
        #synthetic_df = pd.concat([synthetic_df, pd.read_parquet(input_file_b)])
        synthetic_df = pd.concat([synthetic_df, b_json_df])
else:
    synthetic_df = pd.DataFrame(
        columns=["document_id", "position"] + label_categories + analysis_categories + ["inference_time",
                                                                                        "prompt_tokens",
                                                                                        "completion_tokens",
                                                                                        "total_tokens", "text", "input",
                                                                                        "output"])
#synthetic_df = synthetic_df.drop_duplicates()

synthetic_df = synthetic_df.dropna(subset=['text'])
synthetic_df = synthetic_df[synthetic_df['text'] != '']

synthetic_df = synthetic_df.drop_duplicates(subset='text', keep='first')
synthetic_df
# Out:
#                                              document_id  \
# 0      Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 1      Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 2      Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 3      Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 4      Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# ...                                                  ...
# 13960  Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 13961  Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 13962  Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 13963  Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 13964  Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
#
#                                                 position  label_age  \
# 0                                     financial examiner       True
# 1                                                   aide       True
# 2                                               producer      False
# 3                         client services representative      False
# 4                                   student data analyst      False
# ...                                                  ...        ...
# 13960                  Office Assistant/Customer Support       True
# 13961                           city planning technician      False
# 13962                        Academic Grader - Part Time      False
# 13963               Cloud Security Sales Account Manager       True
# 13964  Principal Software Engineer/Manager Software E...       True
#
#        label_disability  label_feminine  label_masculine  label_racial  \
# 0                  True           False             True          True
# 1                  True           False             True          True
# 2                  True            True            False          True
# 3                 False           False             True         False
# 4                  True           False            False          True
# ...                 ...             ...              ...           ...
# 13960              True            True            False          True
# 13961             False           False             True         False
# 13962             False           False            False         False
# 13963             False           False             True         False
# 13964              True           False             True          True
#
#        label_sexuality  label_general  inference_time  ...  \
# 0                False           True       14.452569  ...
# 1                 True           True       21.453533  ...
# 2                False           True       16.085596  ...
# 3                False          False        9.698606  ...
# 4                False          False       14.578910  ...
# ...                ...            ...             ...  ...
# 13960             True           True       16.268484  ...
# 13961            False          False        9.318726  ...
# 13962            False          False       14.667276  ...
# 13963            False           True       17.577055  ...
# 13964            False          False       20.285138  ...
#
#                                                     text  \
# 0      Job Title: Senior Marketing Strategist\n\nWe a...
# 1      Job Title: Gallery Coordinator\n\nWe are seeki...
# 2      Job Title: Marketing Manager\n\nWe are seeking...
# 3      Job Title: Senior Reconnaissance Specialist\n\...
# 4      Job Title: Marketing Director\n\nWe are seekin...
# ...                                                  ...
# 13960  Job Title: Office Assistant/Customer Support\n...
# 13961  Job Title: City Planning Technician\n\nJob Sum...
# 13962  Job Title: Academic Grader - Part Time\n\nJob ...
# 13963  Job Title: Cloud Security Sales Account Manage...
# 13964  Job Title: Principal Software Engineer/Manager...
#
#                                             analysis_age  \
# 0      The term "senior" can imply a preference for o...
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 13960  The term "athletically inclined" may favour yo...
# 13961                                               None
# 13962                                               None
# 13963                                               None
# 13964  The term "junior" introduces an age bias by su...
#
#                                      analysis_disability  \
# 0      The term "attack" can be distressing and is be...
# 1      The term "the differently abled" is biased, as...
# 2      The job description contains a disability bias...
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 13960  The phrase "confined to a wheelchair" implies ...
# 13961                                               None
# 13962                                               None
# 13963                                               None
# 13964  The term "special education students" introduc...
#
#                                        analysis_feminine  \
# 0                                                   None
# 1                                                   None
# 2      The job description contains a feminine bias b...
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 13960  The term "customer-focused" and the emphasis o...
# 13961                                               None
# 13962                                               None
# 13963                                               None
# 13964                                               None
#
#                                       analysis_masculine  \
# 0      The term "team player" can be biased as it mig...
# 1      The term "doorman" is gendered, favouring male...
# 2                                                   None
# 3      The job description introduces masculine bias ...
# 4                                                   None
# ...                                                  ...
# 13960                                               None
# 13961  The job description subtly introduces masculin...
# 13962                                               None
# 13963  The term "aggressive" is a gender-coded word t...
# 13964  The term "baristas" introduces a masculine bia...
#
#                                          analysis_racial  \
# 0      Referring to people as "the undocumented" can ...
# 1      The term "blackmail" associates negative actio...
# 2      The job description contains a racial bias by ...
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 13960  The requirement of a green card excludes non-U...
# 13961                                               None
# 13962                                               None
# 13963                                               None
# 13964  The phrase "White Anglo Saxon communities" int...
#
#                                       analysis_sexuality  \
# 0                                                   None
# 1      The term "stealth" can imply secrecy or deceit...
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 13960  The phrase "gay-friendly individual" is gramma...
# 13961                                               None
# 13962                                               None
# 13963                                               None
# 13964                                               None
#
#                                         analysis_general  \
# 0      The term "feminazi" is highly derogatory and o...
# 1      The term "peanut gallery" has historical class...
# 2      The job description contains a general bias by...
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 13960  The term "implement" subtly favours individual...
# 13961                                               None
# 13962                                               None
# 13963  The term "competitive salary" is vague and can...
# 13964                                               None
#
#                                                    input  \
# 0      [{"role": "user", "content": "The study of red...
# 1      [{"role": "user", "content": "The study of red...
# 2      [{"role": "user", "content": "The study of red...
# 3      [{"role": "user", "content": "The study of red...
# 4      [{"role": "user", "content": "The study of red...
# ...                                                  ...
# 13960  [{"role": "user", "content": "The study of red...
# 13961  [{"role": "user", "content": "The study of red...
# 13962  [{"role": "user", "content": "Your task is to ...
# 13963  [{"role": "user", "content": "The study of red...
# 13964  [{"role": "user", "content": "The study of red...
#
#                                                   output
# 0      Here is a job description that demonstrates th...
# 1      Here is the job description that meets the req...
# 2      Here is a job description that demonstrates th...
# 3      <j>\n\nJob Title: Senior Reconnaissance Specia...
# 4      Here is a job description that demonstrates th...
# ...                                                  ...
# 13960  Here is a job description that meets the requi...
# 13961  <j>\n\nJob Title: City Planning Technician\n\n...
# 13962  <j>\n\nJob Title: Academic Grader - Part Time\...
# 13963  Here is the job description with the specified...
# 13964  <j>\nJob Title: Principal Software Engineer/Ma...
#
# [13949 rows x 23 columns]

# %%
synthetic_df.to_parquet(f'{output_dir}-B/synthetic-biased-job-descriptions.a.parquet')
synthetic_df.to_parquet(f'{output_dir}/synthetic-biased-job-descriptions.parquet')
synthetic_df.to_parquet(
    f'/home/teveritt/Datasets/2024-mcm-everitt-ryan/datasets/synthetic-job-postings/benchmark-inputs/synthetic-biased-job-descriptions.parquet')
synthetic_df.to_json(f'{output_dir}/synthetic-biased-job-descriptions-sync.jsonl', orient='records', lines=True)

# %%
# Dictionary to keep track of the count of samples in each category
category_count = {}
for category in categories:
    category_count[category] = (synthetic_df['label_' + category] == True).sum()

binary_df = synthetic_df[label_categories].astype(int)
binary_df['bias'] = binary_df.sum(axis=1)
category_count['neutral'] = (binary_df['bias'] == 0).sum()
category_count
# Out:
# {'age': 5333,
#  'disability': 5278,
#  'feminine': 3856,
#  'masculine': 3867,
#  'racial': 5166,
#  'sexuality': 5290,
#  'general': 5245,
#  'neutral': 3313}

# %%
category_count['neutral'] = 99999
category_count
# Out:
# {'age': 5321,
#  'disability': 5266,
#  'feminine': 3847,
#  'masculine': 3851,
#  'racial': 5156,
#  'sexuality': 5276,
#  'general': 5234,
#  'neutral': 99999}

# %%
selected_rows = synthetic_df[~synthetic_df['input'].str.contains('embedding the specified biases')]
selected_rows
# Out:
#                                           document_id        position  \
# 14  Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...  civil engineer
#
#     label_age  label_disability  label_feminine  label_masculine  \
# 14      False             False           False            False
#
#     label_racial  label_sexuality  label_general  inference_time  ...  \
# 14         False            False          False        0.405676  ...
#
#                                                  text  analysis_age  \
# 14  **Job Title: Digital Marketing Specialist**\n\...          None
#
#     analysis_disability analysis_feminine analysis_masculine analysis_racial  \
# 14                 None              None               None            None
#
#    analysis_sexuality analysis_general  \
# 14               None             None
#
#                                                 input  \
# 14  [{"role": "user", "content": "The study of red...
#
#                                                output
# 14  <j>\n\n**Job Title: Digital Marketing Speciali...
#
# [1 rows x 23 columns]

# %%
x = synthetic_df[synthetic_df['analysis_age'].isnull()]
x = x[x['analysis_disability'].isnull()]
x = x[x['analysis_racial'].isnull()]
x = x[x['analysis_general'].isnull()]
x = x[x['analysis_sexuality'].isnull()]
x = x[x['analysis_masculine'].isnull()]
x = x[x['analysis_feminine'].isnull()]
x
# Out:
#                                             document_id  \
# 4     Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 7     Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 14    Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 40    Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 46    Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# ...                                                 ...
# 7384  Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 7391  Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 7397  Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 7445  Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# 7457  Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
#
#                                position  label_age  label_disability  \
# 4                  student data analyst      False              True
# 7      technical solutions professional       True              True
# 14                       civil engineer      False             False
# 40             heating plant technician       True              True
# 46                        revenue agent      False             False
# ...                                 ...        ...               ...
# 7384                  content developer      False             False
# 7391                   x-ray technician      False             False
# 7397                   spending analyst      False             False
# 7445  strategic initiatives coordinator      False             False
# 7457              investigative auditor      False             False
#
#       label_feminine  label_masculine  label_racial  label_sexuality  \
# 4              False            False          True            False
# 7               True            False          True             True
# 14             False            False         False            False
# 40             False             True          True             True
# 46              True            False          True            False
# ...              ...              ...           ...              ...
# 7384           False            False          True            False
# 7391           False            False          True            False
# 7397           False            False          True            False
# 7445           False            False         False            False
# 7457           False            False         False            False
#
#       label_general  inference_time  ...  \
# 4             False       14.578910  ...
# 7              True       19.212011  ...
# 14            False        0.405676  ...
# 40            False       17.393419  ...
# 46            False       18.651645  ...
# ...             ...             ...  ...
# 7384          False       10.205500  ...
# 7391          False       14.216972  ...
# 7397          False       12.471678  ...
# 7445           True       13.269978  ...
# 7457           True        9.853694  ...
#
#                                                    text  analysis_age  \
# 4     Job Title: Marketing Director\n\nWe are seekin...          None
# 7     Job Title: Marketing Coordinator\n\nWe are see...          None
# 14    **Job Title: Digital Marketing Specialist**\n\...          None
# 40    Job Title: Longshoreman and Operations Coordin...          None
# 46    Job Title: Marketing Team Lead\n\nWe're lookin...          None
# ...                                                 ...           ...
# 7384  Job Title: Senior Data Analyst\n\nWe are seeki...          None
# 7391  Job Title: Marketing Coordinator\n\nJob Summar...          None
# 7397  Job Title: International Development Coordinat...          None
# 7445  Job Title: Sustainability Coordinator\n\nWe ar...          None
# 7457  Job Title: Elite Marketing Strategist\n\nWe ar...          None
#
#       analysis_disability analysis_feminine analysis_masculine  \
# 4                    None              None               None
# 7                    None              None               None
# 14                   None              None               None
# 40                   None              None               None
# 46                   None              None               None
# ...                   ...               ...                ...
# 7384                 None              None               None
# 7391                 None              None               None
# 7397                 None              None               None
# 7445                 None              None               None
# 7457                 None              None               None
#
#      analysis_racial analysis_sexuality analysis_general  \
# 4               None               None             None
# 7               None               None             None
# 14              None               None             None
# 40              None               None             None
# 46              None               None             None
# ...              ...                ...              ...
# 7384            None               None             None
# 7391            None               None             None
# 7397            None               None             None
# 7445            None               None             None
# 7457            None               None             None
#
#                                                   input  \
# 4     [{"role": "user", "content": "The study of red...
# 7     [{"role": "user", "content": "The study of red...
# 14    [{"role": "user", "content": "The study of red...
# 40    [{"role": "user", "content": "The study of red...
# 46    [{"role": "user", "content": "The study of red...
# ...                                                 ...
# 7384  [{"role": "user", "content": "The study of red...
# 7391  [{"role": "user", "content": "The study of red...
# 7397  [{"role": "user", "content": "The study of red...
# 7445  [{"role": "user", "content": "The study of red...
# 7457  [{"role": "user", "content": "The study of red...
#
#                                                  output
# 4     Here is a job description that demonstrates th...
# 7     <j>\n\nJob Title: Marketing Coordinator\n\nWe ...
# 14    <j>\n\n**Job Title: Digital Marketing Speciali...
# 40    <j>\n\nJob Title: Longshoreman and Operations ...
# 46    Here is a sample job description that demonstr...
# ...                                                 ...
# 7384  <j>\n\nJob Title: Senior Data Analyst\n\nWe ar...
# 7391  <j>\nJob Title: Marketing Coordinator\n\nJob S...
# 7397  <j>\n\nJob Title: International Development Co...
# 7445  <j>\n\nJob Title: Sustainability Coordinator\n...
# 7457  <j>\nJob Title: Elite Marketing Strategist\n\n...
#
# [585 rows x 23 columns]

# %%
import re
import time
import datetime
import pandas as pd
import random
import math
import hashlib


def create_hash(input_string):
    return hashlib.sha256(input_string.encode()).hexdigest()[:10]


def lowercase_tags(text):
    tags = re.findall(r'<\/?\w+', text)
    for tag in tags:
        text = text.replace(tag, tag.lower())
    return text


def extract_job_posting(text):
    content = re.findall(r'<j>(.*?)</j>', text, re.DOTALL)
    ret = [c.strip() for c in content]
    return ret[0] if len(ret) > 0 else text


def find_first_between_tags(file_content, tag):
    start_tag = f"<{tag}>"
    end_tag = f"</{tag}>"

    start_index = file_content.find(start_tag)
    end_index = file_content.find(end_tag)

    if start_index != -1 and end_index != -1:  # tags were found
        start_index += len(start_tag)  # adjust to index after the start tag
        result = file_content[start_index:end_index].strip()  # extract content between tags
        return result

    return None  # tags were not found or improperly formatted


def min_category():
    c = min(category_count.items(), key=lambda item: item[1])
    return c[0]


dry_run = False

while category_count[min_category()] <= size:
    category = min_category()
    position = random_job_title()

    if not dry_run:
        percentage = (category_count[category] / size) * 100
        formatted_percentage = "{:.2f}%".format(percentage)
        print(
            f'{len(synthetic_df)} Generating synthetic for category {category}, position "{position}": {category_count[category]}/{size} [ {formatted_percentage} ]')

    additional_categories = random.sample(categories, k=random.randint(0, max_additional_categories))
    additional_categories = set(additional_categories)
    additional_categories.add(category)

    if category == 'neutral':
        additional_categories.clear()

    # Don't include both to reduce confusing the model
    if 'masculine' in additional_categories and 'feminine' in additional_categories:
        additional_categories.remove('feminine')
        additional_categories.remove('masculine')
        additional_categories.add(random.choice(['masculine', 'feminine']))

    category_terms = {}
    if len(additional_categories) > 0:
        category_sample = int(math.ceil(max_additional_categories / len(additional_categories)))
        category_sample = random.randint(1, category_sample)

        for cat in additional_categories:
            category_terms[cat] = taxonomies[taxonomies['category'] == cat].sample(category_sample)

    # Generate text sample with category information
    #prompt, output = generate_text(category_terms)

    prompt, output, inference_time, prompt_tokens, completion_tokens, total_tokens = generate_text(position,
                                                                                                   category_terms,
                                                                                                   dry_run)

    output = lowercase_tags(output)
    text = find_first_between_tags(output, 'j') if not dry_run else None
    analysis_age = find_first_between_tags(output, 'age')
    analysis_disability = find_first_between_tags(output, 'disability')
    analysis_feminine = find_first_between_tags(output, 'feminine')
    analysis_masculine = find_first_between_tags(output, 'masculine')
    analysis_racial = find_first_between_tags(output, 'racial')
    analysis_sexuality = find_first_between_tags(output, 'sexuality')
    analysis_general = find_first_between_tags(output, 'general')

    category_count[category] += 1

    timestamp = datetime.datetime.now().strftime('%Y%m%d%H%M%S')
    id = create_hash(output) if not dry_run else i
    id = f"{timestamp}:{id}"
    id_m = model_id.replace('/', ':')
    data = {
        "document_id": f'Synthetic:{id_m}:{id}',
        "position": position
    }
    for cat in categories:
        data[f'label_{cat}'] = False

    data['inference_time'] = inference_time
    data['prompt_tokens'] = prompt_tokens
    data['completion_tokens'] = completion_tokens
    data['total_tokens'] = total_tokens
    data['text'] = text
    data['analysis_age'] = analysis_age
    data['analysis_disability'] = analysis_disability
    data['analysis_feminine'] = analysis_feminine
    data['analysis_masculine'] = analysis_masculine
    data['analysis_racial'] = analysis_racial
    data['analysis_sexuality'] = analysis_sexuality
    data['analysis_general'] = analysis_general
    data['input'] = prompt
    data['output'] = output

    for cat in additional_categories:
        data[f'label_{cat}'] = True

    if not dry_run:
        with open(output_file, 'a') as file:
            if not os.stat(output_file).st_size == 0:
                file.write('\n')
            file.write(json.dumps(data))

    synthetic_df = pd.concat([synthetic_df, pd.DataFrame(data, index=[0])], ignore_index=True)
    synthetic_df = synthetic_df.drop_duplicates(subset='text', keep='first')
    synthetic_df.to_parquet(f'{output_dir}/synthetic-biased-job-descriptions.parquet', compression='gzip')

    #break

synthetic_df
# Out:
# 12753 Generating synthetic for category neutral, position "UI/UX developer": 3313/5000 [ 66.26% ]
# 12754 Generating synthetic for category neutral, position "Cyber Threat & Vulnerability Management Chief": 3314/5000 [ 66.28% ]
# 12755 Generating synthetic for category neutral, position "DDSF Fellow": 3315/5000 [ 66.30% ]
# 12756 Generating synthetic for category neutral, position "Global & National Account Consultant": 3316/5000 [ 66.32% ]
# 12757 Generating synthetic for category neutral, position "Senior Staff Storage Engineer": 3317/5000 [ 66.34% ]
# 12758 Generating synthetic for category neutral, position "Instructor - Content Management  Structured Authoring": 3318/5000 [ 66.36% ]
# 12759 Generating synthetic for category neutral, position "Product Development Engineer  Lighting Solutions": 3319/5000 [ 66.38% ]
# 12760 Generating synthetic for category neutral, position "Sales Engineer  Electro Optics": 3320/5000 [ 66.40% ]
# 12761 Generating synthetic for category neutral, position "Contract Technical Trainer/Instructor": 3321/5000 [ 66.42% ]
# 12762 Generating synthetic for category neutral, position "Sales Business Development Manager  Service Provider route-to-market  Latin America": 3322/5000 [ 66.44% ]
# 12763 Generating synthetic for category neutral, position "TAC/HTTS Team Lead": 3323/5000 [ 66.46% ]
# 12764 Generating synthetic for category neutral, position "PC/Network Programmer II": 3324/5000 [ 66.48% ]
# 12765 Generating synthetic for category neutral, position "Fundraising Event Coordinator for Rotaplast": 3325/5000 [ 66.50% ]
# 12766 Generating synthetic for category neutral, position "Analyst - ICR  F5  DSCM": 3326/5000 [ 66.52% ]
# 12767 Generating synthetic for category neutral, position "Head of Business Operations – Vodafone Business Solutions": 3327/5000 [ 66.54% ]
# 12768 Generating synthetic for category neutral, position "Training Coordinator / Curriculum Development / Instructor": 3328/5000 [ 66.56% ]
# 12769 Generating synthetic for category neutral, position "DevOps Engineer / Architect": 3329/5000 [ 66.58% ]
# 12770 Generating synthetic for category neutral, position "Head of Channel Development - Sales  Recruitment  Marketing": 3330/5000 [ 66.60% ]
# 12771 Generating synthetic for category neutral, position "Pre-Sales Designer": 3331/5000 [ 66.62% ]
# 12772 Generating synthetic for category neutral, position "Release Engineering Manager  Technology & Products": 3332/5000 [ 66.64% ]
# 12773 Generating synthetic for category neutral, position "Head Project Engineer": 3333/5000 [ 66.66% ]
# 12774 Generating synthetic for category neutral, position "Co-Manager": 3334/5000 [ 66.68% ]
# 12775 Generating synthetic for category neutral, position "Software Developer/Engineer": 3335/5000 [ 66.70% ]
# 12776 Generating synthetic for category neutral, position "TECHNICAL SUPPORT": 3336/5000 [ 66.72% ]
# 12777 Generating synthetic for category neutral, position "Manager  Global Marketing Programs  HPE Storage": 3337/5000 [ 66.74% ]
# 12778 Generating synthetic for category neutral, position "Manager  Enterprise Architects - Commercial": 3338/5000 [ 66.76% ]
# 12779 Generating synthetic for category neutral, position "IT Developer Intern - Global Replenishment Systems Division": 3339/5000 [ 66.78% ]
# 12780 Generating synthetic for category neutral, position "Account Executive/Business Analyst": 3340/5000 [ 66.80% ]
# 12781 Generating synthetic for category neutral, position "SaaS Infrastructure Architects Team Manager": 3341/5000 [ 66.82% ]
# 12782 Generating synthetic for category neutral, position "Recovering "voluntary early retirement" recipient": 3342/5000 [ 66.84% ]
# 12783 Generating synthetic for category neutral, position "Computer Professional": 3343/5000 [ 66.86% ]
# 12784 Generating synthetic for category neutral, position "EVP  General Counsel & Secretary": 3344/5000 [ 66.88% ]
# 12785 Generating synthetic for category neutral, position "Cloud Computing Intern": 3345/5000 [ 66.90% ]
# 12786 Generating synthetic for category neutral, position "Senior Solutions Engineer - Global Professional Services Organization": 3346/5000 [ 66.92% ]
# 12787 Generating synthetic for category neutral, position "Senior Quality Assurance Software Engineer": 3347/5000 [ 66.94% ]
# 12788 Generating synthetic for category neutral, position "Broadband Technician - Network Engineering": 3348/5000 [ 66.96% ]
# 12789 Generating synthetic for category neutral, position "Software Design Engineer & Software Design Engineer in Test (Intern)": 3349/5000 [ 66.98% ]
# 12790 Generating synthetic for category neutral, position "Dir Application Development\Integration": 3350/5000 [ 67.00% ]
# 12791 Generating synthetic for category neutral, position "Network Support Trainee": 3351/5000 [ 67.02% ]
# 12792 Generating synthetic for category neutral, position "Analyst - Private Wealth Management Operations": 3352/5000 [ 67.04% ]
# 12793 Generating synthetic for category neutral, position "Support Engineer CDMA": 3353/5000 [ 67.06% ]
# 12794 Generating synthetic for category neutral, position "Data Management Analyst": 3354/5000 [ 67.08% ]
# 12795 Generating synthetic for category neutral, position "Product Cybersecurity Vehicle Access and Theft Lead": 3355/5000 [ 67.10% ]
# 12796 Generating synthetic for category neutral, position "Teaching Assistant - Object-Oriented Design": 3356/5000 [ 67.12% ]
# 12797 Generating synthetic for category neutral, position "Apache Tajo Committer": 3357/5000 [ 67.14% ]
# 12798 Generating synthetic for category neutral, position "Senior Strategy Officer  Strategy  Innovation  and Impact": 3358/5000 [ 67.16% ]
# 12799 Generating synthetic for category neutral, position "Manager  Technical Architecture Kodak.com": 3359/5000 [ 67.18% ]
# 12800 Generating synthetic for category neutral, position "Certified Executive Assistant- Support Vice President/General Manager  and staff of IoT Systems": 3360/5000 [ 67.20% ]
# 12801 Generating synthetic for category neutral, position "Network Management Intern": 3361/5000 [ 67.22% ]
# 12802 Generating synthetic for category neutral, position "2nd LAAD BN": 3362/5000 [ 67.24% ]
# 12803 Generating synthetic for category neutral, position "Tableau consultant": 3363/5000 [ 67.26% ]
# 12804 Generating synthetic for category neutral, position "Program Manager / Technology Leader / Software Manager": 3364/5000 [ 67.28% ]
# 12805 Generating synthetic for category neutral, position "Supply Chain Business Manager": 3365/5000 [ 67.30% ]
# 12806 Generating synthetic for category neutral, position "Senior Systems Administrator and Developer": 3366/5000 [ 67.32% ]
# 12807 Generating synthetic for category neutral, position "Technical Lead - Service Provider Support Group": 3367/5000 [ 67.34% ]
# 12808 Generating synthetic for category neutral, position "Senior Account Executive at Salesforce": 3368/5000 [ 67.36% ]
# 12809 Generating synthetic for category neutral, position "Membership Board Advisor": 3369/5000 [ 67.38% ]
# 12810 Generating synthetic for category neutral, position "Senior Analyst  Groupon Goods": 3370/5000 [ 67.40% ]
# 12811 Generating synthetic for category neutral, position "Computer and Network Support Specialist IV": 3371/5000 [ 67.42% ]
# 12812 Generating synthetic for category neutral, position "IT Project Manager  IT Operations": 3372/5000 [ 67.44% ]
# 12813 Generating synthetic for category neutral, position "Network test-integration engineer": 3373/5000 [ 67.46% ]
# 12814 Generating synthetic for category neutral, position "Lead Member Technical Staff: Mobile SDK  Android": 3374/5000 [ 67.48% ]
# 12815 Generating synthetic for category neutral, position "Marketing and Trade Show Coordinator": 3375/5000 [ 67.50% ]
# 12816 Generating synthetic for category neutral, position "Senior Internet Administrator": 3376/5000 [ 67.52% ]
# 12817 Generating synthetic for category neutral, position "Multifamily Real Estate Syndicator": 3377/5000 [ 67.54% ]
# 12818 Generating synthetic for category neutral, position "IT Architect II": 3378/5000 [ 67.56% ]
# 12819 Generating synthetic for category neutral, position "Senior Technical Recruiter - Microsoft-(contract)": 3379/5000 [ 67.58% ]
# 12820 Generating synthetic for category neutral, position "Data Center  Product Sales Specialist": 3380/5000 [ 67.60% ]
# 12821 Generating synthetic for category neutral, position "Open Skies Treaty Inspector / Mission Commander / System Development Director": 3381/5000 [ 67.62% ]
# 12822 Generating synthetic for category neutral, position "Principal Support Engineer (TAC)": 3382/5000 [ 67.64% ]
# 12823 Generating synthetic for category neutral, position "Administrative Specialist": 3383/5000 [ 67.66% ]
# 12824 Generating synthetic for category neutral, position "Senior Director of Digital Marketing": 3384/5000 [ 67.68% ]
# 12825 Generating synthetic for category neutral, position "GIS Specialist": 3385/5000 [ 67.70% ]
# 12826 Generating synthetic for category neutral, position "Support Manager / Escalation Manager": 3386/5000 [ 67.72% ]
# 12827 Generating synthetic for category neutral, position "Network Management Engineer": 3387/5000 [ 67.74% ]
# 12828 Generating synthetic for category neutral, position "Cloud Infrastructure - DevOps Manager": 3388/5000 [ 67.76% ]
# 12829 Generating synthetic for category neutral, position "Capital Budget Manager (IT Strategy & Planning)": 3389/5000 [ 67.78% ]
# 12830 Generating synthetic for category neutral, position "Director of Procurement  Category Management": 3390/5000 [ 67.80% ]
# 12831 Generating synthetic for category neutral, position "IT Infra-structure Engineer (Intern)": 3391/5000 [ 67.82% ]
# 12832 Generating synthetic for category neutral, position "Provisional Broker": 3392/5000 [ 67.84% ]
# 12833 Generating synthetic for category neutral, position "Semiconductor Engineering Consultant": 3393/5000 [ 67.86% ]
# 12834 Generating synthetic for category neutral, position "Vice President and General Manager of Unified Communications Technology Group": 3394/5000 [ 67.88% ]
# 12835 Generating synthetic for category neutral, position "Tax Analyst Intern": 3395/5000 [ 67.90% ]
# 12836 Generating synthetic for category neutral, position "Senior SOX Analyst": 3396/5000 [ 67.92% ]
# 12837 Generating synthetic for category neutral, position "NOC Technician": 3397/5000 [ 67.94% ]
# 12838 Generating synthetic for category neutral, position "Hardware Recruiting Coordinator": 3398/5000 [ 67.96% ]
# 12839 Generating synthetic for category neutral, position "Pinche Intern": 3399/5000 [ 67.98% ]
# 12840 Generating synthetic for category neutral, position "Tagged Customer Support Manager": 3400/5000 [ 68.00% ]
# 12841 Generating synthetic for category neutral, position "Senior Project Manager  BellSouth": 3401/5000 [ 68.02% ]
# 12842 Generating synthetic for category neutral, position "Network & Systems Engineering": 3402/5000 [ 68.04% ]
# 12843 Generating synthetic for category neutral, position "Licensing Support Specialist": 3403/5000 [ 68.06% ]
# 12844 Generating synthetic for category neutral, position "Senior Group Product Manager": 3404/5000 [ 68.08% ]
# 12845 Generating synthetic for category neutral, position "Senior iOS Developer / Web Developer": 3405/5000 [ 68.10% ]
# 12846 Generating synthetic for category neutral, position "Project Manager  Global Field Services": 3406/5000 [ 68.12% ]
# 12847 Generating synthetic for category neutral, position "Global Customer Advocacy Programs": 3407/5000 [ 68.14% ]
# 12848 Generating synthetic for category neutral, position "Security Courseware Developer": 3408/5000 [ 68.16% ]
# 12849 Generating synthetic for category neutral, position "Junior Software QA Engineer": 3409/5000 [ 68.18% ]
# 12850 Generating synthetic for category neutral, position "Social Media Marketing Specialist": 3410/5000 [ 68.20% ]
# 12851 Generating synthetic for category neutral, position "Jazmine Kionna  LLC (Funded by BGV $5K Friday)": 3411/5000 [ 68.22% ]
# 12852 Generating synthetic for category neutral, position "Regional Sales Manager  Architectures  Commercial  Latin America": 3412/5000 [ 68.24% ]
# 12853 Generating synthetic for category neutral, position "Digital Business Analyst": 3413/5000 [ 68.26% ]
# 12854 Generating synthetic for category neutral, position "Network Administrator/engineer": 3414/5000 [ 68.28% ]
# 12855 Generating synthetic for category neutral, position "Co-chair of INSIPID Working Group": 3415/5000 [ 68.30% ]
# 12856 Generating synthetic for category neutral, position "Chief Infrastructure Architect / CCIE Instructor (R/S  Security  SP)": 3416/5000 [ 68.32% ]
# 12857 Generating synthetic for category neutral, position "Systems Engineer Specialist - Public Cloud Solutions": 3417/5000 [ 68.34% ]
# 12858 Generating synthetic for category neutral, position "Head Of Security and DevOps": 3418/5000 [ 68.36% ]
# 12859 Generating synthetic for category neutral, position "Solutions Architect for Security": 3419/5000 [ 68.38% ]
# 12860 Generating synthetic for category neutral, position "Technical Team lead - Senior Technical Support Engineer": 3420/5000 [ 68.40% ]
# 12861 Generating synthetic for category neutral, position "Change Lead - Services Change Leadership (Consultant  Woodside Global Partners  Inc.)": 3421/5000 [ 68.42% ]
# 12862 Generating synthetic for category neutral, position "Business Development Manager  Solution Architect": 3422/5000 [ 68.44% ]
# 12863 Generating synthetic for category neutral, position "Business Liaison": 3423/5000 [ 68.46% ]
# 12864 Generating synthetic for category neutral, position "Revenue Recogntion Analyst": 3424/5000 [ 68.48% ]
# 12865 Generating synthetic for category neutral, position "Global Sales Executive": 3425/5000 [ 68.50% ]
# 12866 Generating synthetic for category neutral, position "Lead Member of Technical Staff  Advanced Technology Research and Development,": 3426/5000 [ 68.52% ]
# 12867 Generating synthetic for category neutral, position "agricultural technician": 3427/5000 [ 68.54% ]
# 12868 Generating synthetic for category neutral, position "Senior Inside Sales Manager - VMware": 3428/5000 [ 68.56% ]
# 12869 Generating synthetic for category neutral, position "Director of Product Management": 3429/5000 [ 68.58% ]
# 12870 Generating synthetic for category neutral, position "DevOps Engineer - Data": 3430/5000 [ 68.60% ]
# 12871 Generating synthetic for category neutral, position "Student Docent": 3431/5000 [ 68.62% ]
# 12872 Generating synthetic for category neutral, position "Head  Technology": 3432/5000 [ 68.64% ]
# 12873 Generating synthetic for category neutral, position "Senior Network Security Engineer": 3433/5000 [ 68.66% ]
# 12874 Generating synthetic for category neutral, position "Client Director": 3434/5000 [ 68.68% ]
# 12875 Generating synthetic for category neutral, position "service desk agent": 3435/5000 [ 68.70% ]
# 12876 Generating synthetic for category neutral, position "Cloud Adminstrator": 3436/5000 [ 68.72% ]
# 12877 Generating synthetic for category neutral, position "Pre-Sales Wireless Architect": 3437/5000 [ 68.74% ]
# 12878 Generating synthetic for category neutral, position "GTI (visitor) Student (Research Assistent)": 3438/5000 [ 68.76% ]
# 12879 Generating synthetic for category neutral, position "Graphics Software Engineer Intern": 3439/5000 [ 68.78% ]
# 12880 Generating synthetic for category neutral, position "Marketing and Social Media Intern": 3440/5000 [ 68.80% ]
# 12881 Generating synthetic for category neutral, position "TAC Engineer  Routing Protocols Team Lead": 3441/5000 [ 68.82% ]
# 12882 Generating synthetic for category neutral, position "PC Assistant": 3442/5000 [ 68.84% ]
# 12883 Generating synthetic for category neutral, position "Software Engineer & Founding Team Member": 3443/5000 [ 68.86% ]
# 12884 Generating synthetic for category neutral, position "Technology Teaching Assistant Mathematics Department": 3444/5000 [ 68.88% ]
# 12885 Generating synthetic for category neutral, position "Server Administrator & Security": 3445/5000 [ 68.90% ]
# 12886 Generating synthetic for category neutral, position "Senior Product Manager  Cloud and Virtualization": 3446/5000 [ 68.92% ]
# 12887 Generating synthetic for category neutral, position "Channel Sales Manager - Americas": 3447/5000 [ 68.94% ]
# 12888 Generating synthetic for category neutral, position "Senior security analyst - CERT Team NAFTA": 3448/5000 [ 68.96% ]
# 12889 Generating synthetic for category neutral, position "Director Product Management - Heroku Connect": 3449/5000 [ 68.98% ]
# 12890 Generating synthetic for category neutral, position "Active Duty F-16 Avionic Systems Specialist (E-4)": 3450/5000 [ 69.00% ]
# 12891 Generating synthetic for category neutral, position "Developer/Manager of OpsCenter Test Engineering": 3451/5000 [ 69.02% ]
# 12892 Generating synthetic for category neutral, position "Principal Research Programmer": 3452/5000 [ 69.04% ]
# 12893 Generating synthetic for category neutral, position "Security SDN Architect": 3453/5000 [ 69.06% ]
# 12894 Generating synthetic for category neutral, position "BI Sales Rep": 3454/5000 [ 69.08% ]
# 12895 Generating synthetic for category neutral, position "Software Infrastructure  Security Business Group": 3455/5000 [ 69.10% ]
# 12896 Generating synthetic for category neutral, position "Product & Technical Marketing": 3456/5000 [ 69.12% ]
# 12897 Generating synthetic for category neutral, position "Director of Business Applications": 3457/5000 [ 69.14% ]
# 12898 Generating synthetic for category neutral, position "Manager  Software Dev": 3458/5000 [ 69.16% ]
# 12899 Generating synthetic for category neutral, position "Lead Security-VPN Web Content Engineer": 3459/5000 [ 69.18% ]
# 12900 Generating synthetic for category neutral, position "Engineering Manager at Twitch": 3460/5000 [ 69.20% ]
# 12901 Generating synthetic for category neutral, position "T2 Network Technical Support": 3461/5000 [ 69.22% ]
# 12902 Generating synthetic for category neutral, position "Managed Services Strategist": 3462/5000 [ 69.24% ]
# 12903 Generating synthetic for category neutral, position "SVP  Customer Success @ Scale": 3463/5000 [ 69.26% ]
# 12904 Generating synthetic for category neutral, position "Financial Investment Intern": 3464/5000 [ 69.28% ]
# 12905 Generating synthetic for category neutral, position "Project Manager  Order Management Large Scale Service": 3465/5000 [ 69.30% ]
# 12906 Generating synthetic for category neutral, position "Program Manager - Customer Care": 3466/5000 [ 69.32% ]
# 12907 Generating synthetic for category neutral, position "Senior Account Manager  Mid-Market": 3467/5000 [ 69.34% ]
# 12908 Generating synthetic for category neutral, position "Partner Interoperability Product Unit Manager  Connected Systems Division": 3468/5000 [ 69.36% ]
# 12909 Generating synthetic for category neutral, position "Senior Software QA Engineer (Systems testing)": 3469/5000 [ 69.38% ]
# 12910 Generating synthetic for category neutral, position "Senior Lead  Test Automation": 3470/5000 [ 69.40% ]
# 12911 Generating synthetic for category neutral, position "Co - Op Web Developer": 3471/5000 [ 69.42% ]
# 12912 Generating synthetic for category neutral, position "Home Service Expert": 3472/5000 [ 69.44% ]
# 12913 Generating synthetic for category neutral, position "Senior Customer Experience Strategist": 3473/5000 [ 69.46% ]
# 12914 Generating synthetic for category neutral, position "Applications Development": 3474/5000 [ 69.48% ]
# 12915 Generating synthetic for category neutral, position "Senior Director  Global ISV and Ecosystem Partners": 3475/5000 [ 69.50% ]
# 12915 Generating synthetic for category neutral, position "Network Control/Administration Director": 3476/5000 [ 69.52% ]
# 12916 Generating synthetic for category neutral, position "Practice Advisor  Workforce Experience - Business Development Executive": 3477/5000 [ 69.54% ]
# 12917 Generating synthetic for category neutral, position "Senior Information Technology Auditor": 3478/5000 [ 69.56% ]
# 12918 Generating synthetic for category neutral, position "Product Manager - UCaaS": 3479/5000 [ 69.58% ]
# 12919 Generating synthetic for category neutral, position "Production Specialist I": 3480/5000 [ 69.60% ]
# 12920 Generating synthetic for category neutral, position "Network System Assistant": 3481/5000 [ 69.62% ]
# 12921 Generating synthetic for category neutral, position "Security Solutions": 3482/5000 [ 69.64% ]
# 12922 Generating synthetic for category neutral, position "Online Lab Assistant": 3483/5000 [ 69.66% ]
# 12923 Generating synthetic for category neutral, position "VSD Software Engineer Co-Op": 3484/5000 [ 69.68% ]
# 12923 Generating synthetic for category neutral, position "Software Quality Engineer  Test Automation": 3485/5000 [ 69.70% ]
# 12924 Generating synthetic for category neutral, position "Technical Leader 1 Engineering": 3486/5000 [ 69.72% ]
# 12925 Generating synthetic for category neutral, position "Global Marketing Events Manager": 3487/5000 [ 69.74% ]
# 12926 Generating synthetic for category neutral, position "Senior Engineering Manager  SPARC Cloud Development and Strategic Customers": 3488/5000 [ 69.76% ]
# 12927 Generating synthetic for category neutral, position "Software Developer Co-op - jStart Emerging technologies": 3489/5000 [ 69.78% ]
# 12928 Generating synthetic for category neutral, position "Technical Manager  Data Analysis and Visualization Group": 3490/5000 [ 69.80% ]
# 12929 Generating synthetic for category neutral, position "Incident Response Engineer": 3491/5000 [ 69.82% ]
# 12930 Generating synthetic for category neutral, position "Actuarial Analyst Intern": 3492/5000 [ 69.84% ]
# 12931 Generating synthetic for category neutral, position "Information Systems Supervisor": 3493/5000 [ 69.86% ]
# 12932 Generating synthetic for category neutral, position "Apple Pay Security Engineer": 3494/5000 [ 69.88% ]
# 12933 Generating synthetic for category neutral, position "Fellow & Chief Software Architect": 3495/5000 [ 69.90% ]
# 12934 Generating synthetic for category neutral, position "Student Fundraiser": 3496/5000 [ 69.92% ]
# 12935 Generating synthetic for category neutral, position "Scientist  Modeling Science  DemandTec Retail Science  EMM": 3497/5000 [ 69.94% ]
# 12936 Generating synthetic for category neutral, position "Assistant Director  Internetworking": 3498/5000 [ 69.96% ]
# 12937 Generating synthetic for category neutral, position "school mental health consultant": 3499/5000 [ 69.98% ]
# 12938 Generating synthetic for category neutral, position "Oracle Database Consultant": 3500/5000 [ 70.00% ]
# 12939 Generating synthetic for category neutral, position "Consumer Insights Intern": 3501/5000 [ 70.02% ]
# 12940 Generating synthetic for category neutral, position "Channel Marketing/Sales Manager": 3502/5000 [ 70.04% ]
# 12941 Generating synthetic for category neutral, position "IBM/ INROADS Intern": 3503/5000 [ 70.06% ]
# 12942 Generating synthetic for category neutral, position "Head of General Merchandise (Non Food)": 3504/5000 [ 70.08% ]
# 12943 Generating synthetic for category neutral, position "Technical Support Representative": 3505/5000 [ 70.10% ]
# 12944 Generating synthetic for category neutral, position "Director  Corporate Development  Greater China Region": 3506/5000 [ 70.12% ]
# 12945 Generating synthetic for category neutral, position "Regional Lead": 3507/5000 [ 70.14% ]
# 12946 Generating synthetic for category neutral, position "SRE for Customer Systems group": 3508/5000 [ 70.16% ]
# 12947 Generating synthetic for category neutral, position "Sales Manager/Enterprise Account Manager": 3509/5000 [ 70.18% ]
# 12948 Generating synthetic for category neutral, position "Product Manager  Ad Technology": 3510/5000 [ 70.20% ]
# 12949 Generating synthetic for category neutral, position "Junior java developer": 3511/5000 [ 70.22% ]
# 12950 Generating synthetic for category neutral, position "Digital/Web Systems Technical and UX Consultant": 3512/5000 [ 70.24% ]
# 12951 Generating synthetic for category neutral, position "Product Manager  Volunteer Management": 3513/5000 [ 70.26% ]
# 12952 Generating synthetic for category neutral, position "Copyeditor": 3514/5000 [ 70.28% ]
# 12953 Generating synthetic for category neutral, position "Sotware Engineering Intern": 3515/5000 [ 70.30% ]
# 12954 Generating synthetic for category neutral, position "Research / Teaching Assistant": 3516/5000 [ 70.32% ]
# 12955 Generating synthetic for category neutral, position "Business and Systems Integration Consultant": 3517/5000 [ 70.34% ]
# 12956 Generating synthetic for category neutral, position "Visiting Associate Professor": 3518/5000 [ 70.36% ]
# 12957 Generating synthetic for category neutral, position "Marketing Commmunications Manager for Worldwide Channels Consultant": 3519/5000 [ 70.38% ]
# 12958 Generating synthetic for category neutral, position "Network and Cybersecurity Consultant": 3520/5000 [ 70.40% ]
# 12959 Generating synthetic for category neutral, position "Solution Architect - Account Executive": 3521/5000 [ 70.42% ]
# 12960 Generating synthetic for category neutral, position "Executive team  IT Director": 3522/5000 [ 70.44% ]
# 12961 Generating synthetic for category neutral, position "Founding Designer": 3523/5000 [ 70.46% ]
# 12962 Generating synthetic for category neutral, position "Product Manager  Monetization": 3524/5000 [ 70.48% ]
# 12963 Generating synthetic for category neutral, position "Senior Director  Global Technical Assistance Center": 3525/5000 [ 70.50% ]
# 12964 Generating synthetic for category neutral, position "ThinkProgress Intern": 3526/5000 [ 70.52% ]
# 12965 Generating synthetic for category neutral, position "Software Quality Assurance Engineer Intern": 3527/5000 [ 70.54% ]
# 12966 Generating synthetic for category neutral, position "Software delivery Engineer": 3528/5000 [ 70.56% ]
# 12967 Generating synthetic for category neutral, position "ICM Developer (Consultant)": 3529/5000 [ 70.58% ]
# 12968 Generating synthetic for category neutral, position "Product Marketing Europe": 3530/5000 [ 70.60% ]
# 12969 Generating synthetic for category neutral, position "Treasurer of Computer Science Graduate Student Association": 3531/5000 [ 70.62% ]
# 12970 Generating synthetic for category neutral, position "Director of Student Success & Corporate Partnerships": 3532/5000 [ 70.64% ]
# 12971 Generating synthetic for category neutral, position "Graphic Designer & Illustrator": 3533/5000 [ 70.66% ]
# 12972 Generating synthetic for category neutral, position "Field application engineer": 3534/5000 [ 70.68% ]
# 12973 Generating synthetic for category neutral, position "Technology & Information Risk Intern": 3535/5000 [ 70.70% ]
# 12974 Generating synthetic for category neutral, position "Vice President of Fundraising": 3536/5000 [ 70.72% ]
# 12975 Generating synthetic for category neutral, position "Java Geospatial Engineer": 3537/5000 [ 70.74% ]
# 12976 Generating synthetic for category neutral, position "Web Editorial Intern": 3538/5000 [ 70.76% ]
# 12977 Generating synthetic for category neutral, position "Agile Program Manager Cloud Platform": 3539/5000 [ 70.78% ]
# 12978 Generating synthetic for category neutral, position "Regional Sales Director  Data Protection/KACE": 3540/5000 [ 70.80% ]
# 12979 Generating synthetic for category neutral, position "Assistant Computer Technician": 3541/5000 [ 70.82% ]
# 12980 Generating synthetic for category neutral, position "Senior Consultant (e- HR )": 3542/5000 [ 70.84% ]
# 12981 Generating synthetic for category neutral, position "Technical Consultant License Management Service": 3543/5000 [ 70.86% ]
# 12982 Generating synthetic for category neutral, position "Deputy Chief of Social Media": 3544/5000 [ 70.88% ]
# 12983 Generating synthetic for category neutral, position "National Account Manager  US Communications Area": 3545/5000 [ 70.90% ]
# 12984 Generating synthetic for category neutral, position "Model": 3546/5000 [ 70.92% ]
# 12985 Generating synthetic for category neutral, position "Service Line Manager  Automotive and strategic industries": 3547/5000 [ 70.94% ]
# 12986 Generating synthetic for category neutral, position "Analyst  Pricing IT": 3548/5000 [ 70.96% ]
# 12987 Generating synthetic for category neutral, position "Test Lead ▪ Microsoft China ▪ Office Apple Experience": 3549/5000 [ 70.98% ]
# 12988 Generating synthetic for category neutral, position "Operations Center Tier 2 Engineer": 3550/5000 [ 71.00% ]
# 12989 Generating synthetic for category neutral, position "State Representative - New Hampshire House of Representatives": 3551/5000 [ 71.02% ]
# 12990 Generating synthetic for category neutral, position "Application Catalyst": 3552/5000 [ 71.04% ]
# 12991 Generating synthetic for category neutral, position "Manager  Engineering Services": 3553/5000 [ 71.06% ]
# 12992 Generating synthetic for category neutral, position "Software Engineering Manager  R&D - SW Ops": 3554/5000 [ 71.08% ]
# 12993 Generating synthetic for category neutral, position "Regional Director  Strategic Sales": 3555/5000 [ 71.10% ]
# 12994 Generating synthetic for category neutral, position "Research Assistant – Aerospace Controls Laboratory": 3556/5000 [ 71.12% ]
# 12995 Generating synthetic for category neutral, position "Global Services/Success Account Manager": 3557/5000 [ 71.14% ]
# 12996 Generating synthetic for category neutral, position "Channel Marketing and Operations": 3558/5000 [ 71.16% ]
# 12997 Generating synthetic for category neutral, position "Senior Systems Engineer/Solutions Design": 3559/5000 [ 71.18% ]
# 12998 Generating synthetic for category neutral, position "Regional HR Business Partner": 3560/5000 [ 71.20% ]
# 12999 Generating synthetic for category neutral, position "Lead Specialist - Technical Services": 3561/5000 [ 71.22% ]
# 13000 Generating synthetic for category neutral, position "Bilingual Global Tech Support / Implementation Specialist": 3562/5000 [ 71.24% ]
# 13001 Generating synthetic for category neutral, position "Latin America South - NetVista Brand Manager": 3563/5000 [ 71.26% ]
# 13002 Generating synthetic for category neutral, position "Senior Product Manger": 3564/5000 [ 71.28% ]
# 13003 Generating synthetic for category neutral, position "Program Manager  Trade Compliance": 3565/5000 [ 71.30% ]
# 13004 Generating synthetic for category neutral, position "SENIOR ARCHITECT ~ IT Life Sciences Consultant": 3566/5000 [ 71.32% ]
# 13005 Generating synthetic for category neutral, position "Director of Business Development & Marketing (Contract)": 3567/5000 [ 71.34% ]
# 13006 Generating synthetic for category neutral, position "Researcher  Cuba Classic Series": 3568/5000 [ 71.36% ]
# 13007 Generating synthetic for category neutral, position "Managing Network Architect": 3569/5000 [ 71.38% ]
# 13008 Generating synthetic for category neutral, position "Service Marketing Manager": 3570/5000 [ 71.40% ]
# 13009 Generating synthetic for category neutral, position "Global Program Manager - Information Security": 3571/5000 [ 71.42% ]
# 13010 Generating synthetic for category neutral, position "Associate Technical Advisor": 3572/5000 [ 71.44% ]
# 13011 Generating synthetic for category neutral, position "Senior Data Sales Manager": 3573/5000 [ 71.46% ]
# 13012 Generating synthetic for category neutral, position "Technical Group Lead": 3574/5000 [ 71.48% ]
# 13013 Generating synthetic for category neutral, position "Customer and SDK Support Engineer": 3575/5000 [ 71.50% ]
# 13014 Generating synthetic for category neutral, position "Regional Manager  Sales & Market Development": 3576/5000 [ 71.52% ]
# 13015 Generating synthetic for category neutral, position "Client Support Ninja": 3577/5000 [ 71.54% ]
# 13016 Generating synthetic for category neutral, position "Senior Engineering Services Architect": 3578/5000 [ 71.56% ]
# 13017 Generating synthetic for category neutral, position "Asst. Systems Engineer": 3579/5000 [ 71.58% ]
# 13018 Generating synthetic for category neutral, position "Director of Education Services": 3580/5000 [ 71.60% ]
# 13019 Generating synthetic for category neutral, position "Independent Computer Consultant": 3581/5000 [ 71.62% ]
# 13020 Generating synthetic for category neutral, position "Student Data Assistant": 3582/5000 [ 71.64% ]
# 13021 Generating synthetic for category neutral, position "Community Manager": 3583/5000 [ 71.66% ]
# 13022 Generating synthetic for category neutral, position "Deputy Field Organizer": 3584/5000 [ 71.68% ]
# 13023 Generating synthetic for category neutral, position "Application Architect V - Contractor": 3585/5000 [ 71.70% ]
# 13024 Generating synthetic for category neutral, position "Product Partnerships Manager - Gaming": 3586/5000 [ 71.72% ]
# 13025 Generating synthetic for category neutral, position "Marketing Programs Supervisor": 3587/5000 [ 71.74% ]
# 13026 Generating synthetic for category neutral, position "Wireless Network Specialist": 3588/5000 [ 71.76% ]
# 13027 Generating synthetic for category neutral, position "Senior Software Development Engineer (Web development -Backend -Services -Datascience-Analytics)": 3589/5000 [ 71.78% ]
# 13028 Generating synthetic for category neutral, position "Engineering Vice President (VP)": 3590/5000 [ 71.80% ]
# 13029 Generating synthetic for category neutral, position "Services Sales Manager - Caribbean": 3591/5000 [ 71.82% ]
# 13030 Generating synthetic for category neutral, position "Senior Program Manager  Customer Experience Platform Product Development PMO": 3592/5000 [ 71.84% ]
# 13031 Generating synthetic for category neutral, position "Graduate Student  Researcher  Teaching Assistant": 3593/5000 [ 71.86% ]
# 13032 Generating synthetic for category neutral, position "Software Quality Assurance Engineer/scrum master": 3594/5000 [ 71.88% ]
# 13033 Generating synthetic for category neutral, position "Product Manager  Medidata Grants Manager": 3595/5000 [ 71.90% ]
# 13034 Generating synthetic for category neutral, position "Presales Engineering Manager  Storage and Virtualization": 3596/5000 [ 71.92% ]
# 13035 Generating synthetic for category neutral, position "Senior Windows/Citrix Engineer": 3597/5000 [ 71.94% ]
# 13036 Generating synthetic for category neutral, position "Asst Manager NOC": 3598/5000 [ 71.96% ]
# 13037 Generating synthetic for category neutral, position "Undergraduate Research Assistant (Family Medicine)": 3599/5000 [ 71.98% ]
# 13038 Generating synthetic for category neutral, position "IT - Sales Liaison - Global Client Services": 3600/5000 [ 72.00% ]
# 13039 Generating synthetic for category neutral, position "Prep Cook": 3601/5000 [ 72.02% ]
# 13040 Generating synthetic for category neutral, position "VP  Product Data Science": 3602/5000 [ 72.04% ]
# 13041 Generating synthetic for category neutral, position "Health Information Associate": 3603/5000 [ 72.06% ]
# 13042 Generating synthetic for category neutral, position "Data Center Consulting systems engineering": 3604/5000 [ 72.08% ]
# 13043 Generating synthetic for category neutral, position "Strategic Account Manager - Financial Services": 3605/5000 [ 72.10% ]
# 13044 Generating synthetic for category neutral, position "Mathematics Course Assistant": 3606/5000 [ 72.12% ]
# 13045 Generating synthetic for category neutral, position "Website Developer": 3607/5000 [ 72.14% ]
# 13046 Generating synthetic for category neutral, position "Senior Principal  Application Operations": 3608/5000 [ 72.16% ]
# 13047 Generating synthetic for category neutral, position "Oracle Apps DBA/Technical Architect (Staff Consultant)": 3609/5000 [ 72.18% ]
# 13048 Generating synthetic for category neutral, position "Senior Manager- Enterprise Information Management": 3610/5000 [ 72.20% ]
# 13049 Generating synthetic for category neutral, position "Video Cloud Services Integration & Test Senior Manager": 3611/5000 [ 72.22% ]
# 13050 Generating synthetic for category neutral, position "Public Site Consultant": 3612/5000 [ 72.24% ]
# 13051 Generating synthetic for category neutral, position "Senior Machine Learning SWE": 3613/5000 [ 72.26% ]
# 13052 Generating synthetic for category neutral, position "React Native developer": 3614/5000 [ 72.28% ]
# 13053 Generating synthetic for category neutral, position "Oracle Fusion Middleware Administrator  Exalogic Engineer  Senior Associate": 3615/5000 [ 72.30% ]
# 13054 Generating synthetic for category neutral, position "Quality Assurance Analyst and Scrum Master": 3616/5000 [ 72.32% ]
# 13055 Generating synthetic for category neutral, position "Manager Aerial Construction": 3617/5000 [ 72.34% ]
# 13055 Generating synthetic for category neutral, position "WW Partner Support Manager": 3618/5000 [ 72.36% ]
# 13056 Generating synthetic for category neutral, position "Application Security Consultant": 3619/5000 [ 72.38% ]
# 13057 Generating synthetic for category neutral, position "Training Systems Engineer": 3620/5000 [ 72.40% ]
# 13058 Generating synthetic for category neutral, position "CTO (Software) and co-founder": 3621/5000 [ 72.42% ]
# 13059 Generating synthetic for category neutral, position "Manager  Talent and Organization Performance Team": 3622/5000 [ 72.44% ]
# 13060 Generating synthetic for category neutral, position "Devops/Production Engineer": 3623/5000 [ 72.46% ]
# 13061 Generating synthetic for category neutral, position "Snr. Project Manager": 3624/5000 [ 72.48% ]
# 13062 Generating synthetic for category neutral, position "IT 224 Lab Instructor": 3625/5000 [ 72.50% ]
# 13063 Generating synthetic for category neutral, position "Manager  Market Research/MIS,": 3626/5000 [ 72.52% ]
# 13064 Generating synthetic for category neutral, position "Systems Engineer Manager for Enterprise Technologies": 3627/5000 [ 72.54% ]
# 13065 Generating synthetic for category neutral, position "Manager  Global Network & Telecom": 3628/5000 [ 72.56% ]
# 13066 Generating synthetic for category neutral, position "RF Wireless Engineer 4": 3629/5000 [ 72.58% ]
# 13067 Generating synthetic for category neutral, position "Level 2 Tech Support": 3630/5000 [ 72.60% ]
# 13068 Generating synthetic for category neutral, position "Delivery Prime & Program Manager - AT&T Mobility Datacenters": 3631/5000 [ 72.62% ]
# 13069 Generating synthetic for category neutral, position "Architect | Lead - IT": 3632/5000 [ 72.64% ]
# 13070 Generating synthetic for category neutral, position "technical Yahoo!": 3633/5000 [ 72.66% ]
# 13071 Generating synthetic for category neutral, position "Agile Coach - Agile Project Manager": 3634/5000 [ 72.68% ]
# 13072 Generating synthetic for category neutral, position "Senior Technical Marketing Engineer | Data Center   Virtualization  Storage and Cloud Solutions": 3635/5000 [ 72.70% ]
# 13073 Generating synthetic for category neutral, position "Network Engineer - MPLS Core": 3636/5000 [ 72.72% ]
# 13074 Generating synthetic for category neutral, position "Hospital Corpsman Third Class (Supervisor)": 3637/5000 [ 72.74% ]
# 13075 Generating synthetic for category neutral, position "Hong Kong Studio - Engineering": 3638/5000 [ 72.76% ]
# 13076 Generating synthetic for category neutral, position "Senior Manager  Infrastructure Global Operations": 3639/5000 [ 72.78% ]
# 13077 Generating synthetic for category neutral, position "Global Information Security IT Analyst": 3640/5000 [ 72.80% ]
# 13078 Generating synthetic for category neutral, position "Television News Producer": 3641/5000 [ 72.82% ]
# 13079 Generating synthetic for category neutral, position "Sales Manager  Financial Services": 3642/5000 [ 72.84% ]
# 13080 Generating synthetic for category neutral, position "Director of Localization": 3643/5000 [ 72.86% ]
# 13081 Generating synthetic for category neutral, position "Member Tech Staff": 3644/5000 [ 72.88% ]
# 13082 Generating synthetic for category neutral, position "FPGA engineer": 3645/5000 [ 72.90% ]
# 13083 Generating synthetic for category neutral, position "ERP Production Support/ Analyst": 3646/5000 [ 72.92% ]
# 13084 Generating synthetic for category neutral, position "Web Developer - HubSpot Product & Engineering (Design Assets Team)": 3647/5000 [ 72.94% ]
# 13085 Generating synthetic for category neutral, position "CPOC (Customer Proof of Concept) Engineer": 3648/5000 [ 72.96% ]
# 13086 Generating synthetic for category neutral, position "Vice President & GM  Unified Communications Security": 3649/5000 [ 72.98% ]
# 13087 Generating synthetic for category neutral, position "Manager  Senior Manager  Director of Events (12 years)": 3650/5000 [ 73.00% ]
# 13088 Generating synthetic for category neutral, position "APAC OEM/ODM Technical Account Manager": 3651/5000 [ 73.02% ]
# 13089 Generating synthetic for category neutral, position "Manager Business Applications | Oracle Financial (Internal Product Manager)": 3652/5000 [ 73.04% ]
# 13090 Generating synthetic for category neutral, position "Legal & Criminal Justice Intern in ADA's office": 3653/5000 [ 73.06% ]
# 13091 Generating synthetic for category neutral, position "Network Engineer - Video": 3654/5000 [ 73.08% ]
# 13092 Generating synthetic for category neutral, position "Assistant Contract Manager": 3655/5000 [ 73.10% ]
# 13093 Generating synthetic for category neutral, position "Graduate Teaching Assistant  Telecommunications department": 3656/5000 [ 73.12% ]
# 13094 Generating synthetic for category neutral, position "Associate Client Advisor": 3657/5000 [ 73.14% ]
# 13095 Generating synthetic for category neutral, position "Manager - Cisco IAM - Compliance": 3658/5000 [ 73.16% ]
# 13096 Generating synthetic for category neutral, position "Transportation Specialist": 3659/5000 [ 73.18% ]
# 13097 Generating synthetic for category neutral, position "MBA Candidate  Class of 2018": 3660/5000 [ 73.20% ]
# 13098 Generating synthetic for category neutral, position "Staff Software Engineer (Packet Forwarding)": 3661/5000 [ 73.22% ]
# 13099 Generating synthetic for category neutral, position "Web Communications Assistant": 3662/5000 [ 73.24% ]
# 13100 Generating synthetic for category neutral, position "Knowledge Expert & Customer Analytics Manager": 3663/5000 [ 73.26% ]
# 13101 Generating synthetic for category neutral, position "Director - IT Services and WAN Systems Engineering": 3664/5000 [ 73.28% ]
# 13102 Generating synthetic for category neutral, position "Identity Architect": 3665/5000 [ 73.30% ]
# 13103 Generating synthetic for category neutral, position "Systems Engineer (BMS - Energy Harvesting)": 3666/5000 [ 73.32% ]
# 13104 Generating synthetic for category neutral, position "Marketing Consultant (Contractor)": 3667/5000 [ 73.34% ]
# 13105 Generating synthetic for category neutral, position "Communications Strategist": 3668/5000 [ 73.36% ]
# 13106 Generating synthetic for category neutral, position "Assistant Men's JV Basketball Coach": 3669/5000 [ 73.38% ]
# 13107 Generating synthetic for category neutral, position "Staff Engineer/Project management": 3670/5000 [ 73.40% ]
# 13108 Generating synthetic for category neutral, position "Chief Technical Architect - Converged Cloud User Experience": 3671/5000 [ 73.42% ]
# 13109 Generating synthetic for category neutral, position "Senior Software Engineer / Program Manager": 3672/5000 [ 73.44% ]
# 13110 Generating synthetic for category neutral, position "Senior Manager  Learning and Development - SDWAN": 3673/5000 [ 73.46% ]
# 13111 Generating synthetic for category neutral, position "Industry marketing consultant": 3674/5000 [ 73.48% ]
# 13112 Generating synthetic for category neutral, position "Senior Manager  Strategy & Business Development - Networking and Security Business Group": 3675/5000 [ 73.50% ]
# 13113 Generating synthetic for category neutral, position "Senior Enterprise Systems Engineer": 3676/5000 [ 73.52% ]
# 13114 Generating synthetic for category neutral, position "Software Engineer - Wireless": 3677/5000 [ 73.54% ]
# 13115 Generating synthetic for category neutral, position "Product Manager - Clinical Solutions": 3678/5000 [ 73.56% ]
# 13116 Generating synthetic for category neutral, position "Staff Software Development Engineer in Automation": 3679/5000 [ 73.58% ]
# 13117 Generating synthetic for category neutral, position "Site Reliability Engineer Intern": 3680/5000 [ 73.60% ]
# 13118 Generating synthetic for category neutral, position "Software Development Engineer in Test  II - Online Advertising": 3681/5000 [ 73.62% ]
# 13119 Generating synthetic for category neutral, position "Citrix Online QA Engineer  GoToAssistCorporate Product": 3682/5000 [ 73.64% ]
# 13120 Generating synthetic for category neutral, position "Technical Architect - Converged Infrastructure Security": 3683/5000 [ 73.66% ]
# 13121 Generating synthetic for category neutral, position "Senior Software Engineer – Mobile content monetization and billing": 3684/5000 [ 73.68% ]
# 13122 Generating synthetic for category neutral, position "Founder and Deputy Director  Critical Infrastructure Protection (CIP) Integration Staff": 3685/5000 [ 73.70% ]
# 13123 Generating synthetic for category neutral, position "Senior Manger Sales Engineering North America": 3686/5000 [ 73.72% ]
# 13124 Generating synthetic for category neutral, position "Data Management Intern": 3687/5000 [ 73.74% ]
# 13125 Generating synthetic for category neutral, position "energy policy advisor": 3688/5000 [ 73.76% ]
# 13126 Generating synthetic for category neutral, position "Solutions Architect Consultant - NYC Site Lead": 3689/5000 [ 73.78% ]
# 13127 Generating synthetic for category neutral, position "Digital Administrator": 3690/5000 [ 73.80% ]
# 13128 Generating synthetic for category neutral, position "Senior Software QA Engineer - BGP/multicast": 3691/5000 [ 73.82% ]
# 13129 Generating synthetic for category neutral, position "Lead IT Analyst": 3692/5000 [ 73.84% ]
# 13130 Generating synthetic for category neutral, position "Exam Corrector": 3693/5000 [ 73.86% ]
# 13131 Generating synthetic for category neutral, position "Director of Business Development / Online Communications": 3694/5000 [ 73.88% ]
# 13132 Generating synthetic for category neutral, position "Messaging Security Product Sales Engineer": 3695/5000 [ 73.90% ]
# 13133 Generating synthetic for category neutral, position "Senior Director  Products and Solutions Marketing": 3696/5000 [ 73.92% ]
# 13134 Generating synthetic for category neutral, position "Paralegal": 3697/5000 [ 73.94% ]
# 13135 Generating synthetic for category neutral, position "EMI/RFI Senior Staff Engineer": 3698/5000 [ 73.96% ]
# 13136 Generating synthetic for category neutral, position "Senior Marketing Program Manager   Healthcare & Life Sciences": 3699/5000 [ 73.98% ]
# 13137 Generating synthetic for category neutral, position "System Implementor/Network Administrator": 3700/5000 [ 74.00% ]
# 13138 Generating synthetic for category neutral, position "Unit Security Manager": 3701/5000 [ 74.02% ]
# 13139 Generating synthetic for category neutral, position "CRN Test Center": 3702/5000 [ 74.04% ]
# 13140 Generating synthetic for category neutral, position "Senior Manager Global Technology": 3703/5000 [ 74.06% ]
# 13141 Generating synthetic for category neutral, position "Student Co-Op Technical I  TDP-TO": 3704/5000 [ 74.08% ]
# 13142 Generating synthetic for category neutral, position "Engineering Manager/Technical Leader  for In Country Certifications": 3705/5000 [ 74.10% ]
# 13143 Generating synthetic for category neutral, position "R&D customer and post-sale support engineer": 3706/5000 [ 74.12% ]
# 13144 Generating synthetic for category neutral, position "Services Product Marketing Manager": 3707/5000 [ 74.14% ]
# 13145 Generating synthetic for category neutral, position "Infotainment Cybersecurity": 3708/5000 [ 74.16% ]
# 13146 Generating synthetic for category neutral, position "BIlingual Data Collection Researcher": 3709/5000 [ 74.18% ]
# 13147 Generating synthetic for category neutral, position "Senior Manager - SaaS Operations Support and Compliance": 3710/5000 [ 74.20% ]
# 13148 Generating synthetic for category neutral, position "Senior Management Reporting Analyst – Corporate Accounting": 3711/5000 [ 74.22% ]
# 13149 Generating synthetic for category neutral, position "Cloud Integrations Engineer": 3712/5000 [ 74.24% ]
# 13150 Generating synthetic for category neutral, position "HW Engineer": 3713/5000 [ 74.26% ]
# 13151 Generating synthetic for category neutral, position "Senior Manager - Virtualization & Automation": 3714/5000 [ 74.28% ]
# 13152 Generating synthetic for category neutral, position "Middle Enterprise Account Executive": 3715/5000 [ 74.30% ]
# ...
# 13845 Generating synthetic for category feminine, position "United Nations - 48th GSPUN Graduated": 4047/5000 [ 80.94% ]
# 13846 Generating synthetic for category masculine, position "Senior Systems Engineer  NetApp FAS  F5 Networks  Microsoft SQL": 4047/5000 [ 80.94% ]
# 13847 Generating synthetic for category neutral, position "Office Manager / Event Coordinator / Board President": 4047/5000 [ 80.94% ]
# 13848 Generating synthetic for category feminine, position "Senior Business Ops Manager  Customer and Partner Services": 4048/5000 [ 80.96% ]
# 13849 Generating synthetic for category masculine, position "Recruiter / HR Administrator": 4048/5000 [ 80.96% ]
# 13850 Generating synthetic for category neutral, position "Senior Report Writer @ Applied Materials": 4048/5000 [ 80.96% ]
# 13851 Generating synthetic for category feminine, position "design Engineer": 4049/5000 [ 80.98% ]
# 13852 Generating synthetic for category masculine, position "Course Grader - (Cloud Computing - EECS-542)": 4049/5000 [ 80.98% ]
# 13853 Generating synthetic for category neutral, position "West and Central Area Leader  Enterprise Business Solutions": 4049/5000 [ 80.98% ]
# 13854 Generating synthetic for category feminine, position "Onboard Coordinador": 4050/5000 [ 81.00% ]
# 13855 Generating synthetic for category masculine, position "Antenna Specialist": 4050/5000 [ 81.00% ]
# 13856 Generating synthetic for category neutral, position "Director of Events and Catering": 4050/5000 [ 81.00% ]
# 13856 Generating synthetic for category feminine, position "network engineer": 4051/5000 [ 81.02% ]
# 13857 Generating synthetic for category masculine, position "Online Commerce Business Development Manager": 4051/5000 [ 81.02% ]
# 13858 Generating synthetic for category neutral, position "Product Line Manager  Consumer and Embedded": 4051/5000 [ 81.02% ]
# 13859 Generating synthetic for category feminine, position "Senior Business Systems Analyst  IT Dept": 4052/5000 [ 81.04% ]
# 13860 Generating synthetic for category masculine, position "Commercial Account Manager - NE Ohio": 4052/5000 [ 81.04% ]
# 13861 Generating synthetic for category neutral, position "SIP Development Engineer at INDRA SISTEMAS": 4052/5000 [ 81.04% ]
# 13862 Generating synthetic for category feminine, position "Chief Technology Officer (CTO)": 4053/5000 [ 81.06% ]
# 13863 Generating synthetic for category masculine, position "Full Stack UI Engineer for J Crew": 4053/5000 [ 81.06% ]
# 13864 Generating synthetic for category neutral, position "Senior Rules and UI Developer": 4053/5000 [ 81.06% ]
# 13865 Generating synthetic for category feminine, position "Client Networking Services": 4054/5000 [ 81.08% ]
# 13866 Generating synthetic for category masculine, position "Senior Community Manager": 4054/5000 [ 81.08% ]
# 13867 Generating synthetic for category neutral, position "Customer Response Center Associate": 4054/5000 [ 81.08% ]
# 13867 Generating synthetic for category feminine, position "Associate Systems Software Specialist": 4055/5000 [ 81.10% ]
# 13868 Generating synthetic for category masculine, position "Senior Unified Communication Consultant": 4055/5000 [ 81.10% ]
# 13869 Generating synthetic for category neutral, position "Senior Applications Sales Representative": 4055/5000 [ 81.10% ]
# 13870 Generating synthetic for category feminine, position "Teaching Assistant - Computer Organization and Programming": 4056/5000 [ 81.12% ]
# 13871 Generating synthetic for category masculine, position "Communications Hardware Specialist III  Team Lead": 4056/5000 [ 81.12% ]
# 13872 Generating synthetic for category neutral, position "SAP Transportation Management (TM 9.1)/Project Manager/ Sales Executive": 4056/5000 [ 81.12% ]
# 13873 Generating synthetic for category feminine, position "Regional Manager  Facilities": 4057/5000 [ 81.14% ]
# 13874 Generating synthetic for category masculine, position "Sales Manager- Security and Risk": 4057/5000 [ 81.14% ]
# 13875 Generating synthetic for category neutral, position "Software Engineer - Build Architecture  Build Operations": 4057/5000 [ 81.14% ]
# 13876 Generating synthetic for category feminine, position "Consulting Architect - APAC": 4058/5000 [ 81.16% ]
# 13877 Generating synthetic for category masculine, position "Development Lead/Manager": 4058/5000 [ 81.16% ]
# 13878 Generating synthetic for category neutral, position "Project / Program Manager - Network Implementation": 4058/5000 [ 81.16% ]
# 13879 Generating synthetic for category feminine, position "IN-VAS Engineer (IP/MPBN Network Operation)": 4059/5000 [ 81.18% ]
# 13880 Generating synthetic for category masculine, position "Marketing Manager - EMEA and AsiaPac": 4059/5000 [ 81.18% ]
# 13881 Generating synthetic for category neutral, position "NETWORK CONSULTING ENGINEER - GLOBAL FINANCIAL": 4059/5000 [ 81.18% ]
# 13882 Generating synthetic for category feminine, position "Senior Software consultant": 4060/5000 [ 81.20% ]
# 13883 Generating synthetic for category masculine, position "Software Developer/Entry Level": 4060/5000 [ 81.20% ]
# 13884 Generating synthetic for category neutral, position "Senior Product Project Manager": 4060/5000 [ 81.20% ]
# 13885 Generating synthetic for category feminine, position "Polymer and Semiconductor Testing Engineer": 4061/5000 [ 81.22% ]
# 13886 Generating synthetic for category masculine, position "US Service Provider East Regional Manager": 4061/5000 [ 81.22% ]
# 13887 Generating synthetic for category neutral, position "Consultant at PG&E": 4061/5000 [ 81.22% ]
# 13888 Generating synthetic for category feminine, position "Customer Insights Research Manager": 4062/5000 [ 81.24% ]
# 13889 Generating synthetic for category masculine, position "Software Engineer | Java | J2EE | Web Services | SAAJ | SOAP | XML": 4062/5000 [ 81.24% ]
# 13890 Generating synthetic for category neutral, position "Project Lead/Programmer Analyst": 4062/5000 [ 81.24% ]
# 13891 Generating synthetic for category feminine, position "Fellowship": 4063/5000 [ 81.26% ]
# 13892 Generating synthetic for category masculine, position "Genomic Analyst / Developer (Tenenbaum Lab)": 4063/5000 [ 81.26% ]
# 13893 Generating synthetic for category neutral, position "Computer Sales Specialist": 4063/5000 [ 81.26% ]
# 13894 Generating synthetic for category feminine, position "Azure Principal Solutions Specialist": 4064/5000 [ 81.28% ]
# 13895 Generating synthetic for category masculine, position "Director - Collaboration Solutions (State and Local Gov)": 4064/5000 [ 81.28% ]
# 13896 Generating synthetic for category neutral, position "Senior Manager  Test Engineering and Operations": 4064/5000 [ 81.28% ]
# 13897 Generating synthetic for category feminine, position "Senior New Business Development Executive": 4065/5000 [ 81.30% ]
# 13898 Generating synthetic for category masculine, position "Content Author for official Cisco CCIE Security Written Exam (Contract)": 4065/5000 [ 81.30% ]
# 13899 Generating synthetic for category neutral, position "Client Service Analyst": 4065/5000 [ 81.30% ]
# 13900 Generating synthetic for category feminine, position "Vice President Marketing  AutoCAD and Subscription": 4066/5000 [ 81.32% ]
# 13901 Generating synthetic for category masculine, position "B2C Mobile Web Developer - React": 4066/5000 [ 81.32% ]
# 13902 Generating synthetic for category neutral, position "Product Manager  FlashSoft": 4066/5000 [ 81.32% ]
# 13903 Generating synthetic for category feminine, position "MPS Sales Specialist": 4067/5000 [ 81.34% ]
# 13904 Generating synthetic for category masculine, position "Sales Guy": 4067/5000 [ 81.34% ]
# 13905 Generating synthetic for category neutral, position "Program Manager  Software Services Entitlement and Compliance PMO": 4067/5000 [ 81.34% ]
# 13906 Generating synthetic for category feminine, position "Business Development & Sales Operations": 4068/5000 [ 81.36% ]
# 13907 Generating synthetic for category masculine, position "Senior Director Online Marketing  APAC": 4068/5000 [ 81.36% ]
# 13908 Generating synthetic for category neutral, position "Communications Specialist - Mobility Business Group": 4068/5000 [ 81.36% ]
# 13909 Generating synthetic for category feminine, position "Senior Software Engineer  Storage Management": 4069/5000 [ 81.38% ]
# 13910 Generating synthetic for category masculine, position "Community Engagement Manager": 4069/5000 [ 81.38% ]
# 13911 Generating synthetic for category neutral, position "Senior Software Developer  Lead in Customer Development": 4069/5000 [ 81.38% ]
# 13912 Generating synthetic for category feminine, position "Senior Site Engineer": 4070/5000 [ 81.40% ]
# 13913 Generating synthetic for category masculine, position "Subject Matter Expert - Network Security": 4070/5000 [ 81.40% ]
# 13914 Generating synthetic for category neutral, position "Technical Instructor / Consultant": 4070/5000 [ 81.40% ]
# 13915 Generating synthetic for category feminine, position "Chief Solutions Architect  Public Sector": 4071/5000 [ 81.42% ]
# 13916 Generating synthetic for category masculine, position "Albertsons Inc. (Wipro Technologies)": 4071/5000 [ 81.42% ]
# 13917 Generating synthetic for category neutral, position "Program Manager  Marketing  Communications & Programs": 4071/5000 [ 81.42% ]
# 13918 Generating synthetic for category feminine, position "VAR Program Manager": 4072/5000 [ 81.44% ]
# 13919 Generating synthetic for category masculine, position "Online Proselyting Software Developer": 4072/5000 [ 81.44% ]
# 13920 Generating synthetic for category neutral, position "Senior Product Manager  Architect  Virtualized Packet Core": 4072/5000 [ 81.44% ]
# 13921 Generating synthetic for category feminine, position "Linux Support Team - Instructor / Mentor": 4073/5000 [ 81.46% ]
# 13922 Generating synthetic for category masculine, position "Web Programming Teaching Assistant": 4073/5000 [ 81.46% ]
# 13923 Generating synthetic for category neutral, position "Firmware Developer - R&D": 4073/5000 [ 81.46% ]
# 13924 Generating synthetic for category feminine, position "Sales & Channel Strategy Manager  Euromed After-sales Division (9 countries)": 4074/5000 [ 81.48% ]
# 13925 Generating synthetic for category masculine, position "Online Marketing Contractor  Demand Generation": 4074/5000 [ 81.48% ]
# 13926 Generating synthetic for category neutral, position "Business Reporter": 4074/5000 [ 81.48% ]
# 13927 Generating synthetic for category feminine, position "Coop": 4075/5000 [ 81.50% ]
# 13928 Generating synthetic for category masculine, position "Systems Engineering Manager - GovED": 4075/5000 [ 81.50% ]
# 13929 Generating synthetic for category neutral, position "Brand and Product Marketing  Globalization  and Communications Strategy Consulting": 4075/5000 [ 81.50% ]
# 13930 Generating synthetic for category feminine, position "Linux System Manager": 4076/5000 [ 81.52% ]
# 13931 Generating synthetic for category masculine, position "Software Secure Architect": 4076/5000 [ 81.52% ]
# 13932 Generating synthetic for category neutral, position "Treasury Manager  -  Capital Markets and Corporate Finance": 4076/5000 [ 81.52% ]
# 13933 Generating synthetic for category feminine, position "DTV Marketing director": 4077/5000 [ 81.54% ]
# 13934 Generating synthetic for category masculine, position "Personal Assistant to Mark Elices": 4077/5000 [ 81.54% ]
# 13935 Generating synthetic for category neutral, position "Principal Opto-Mechanical Engineer": 4077/5000 [ 81.54% ]
# 13936 Generating synthetic for category feminine, position "Speaker and Mentor": 4078/5000 [ 81.56% ]
# 13937 Generating synthetic for category masculine, position "Senior Client Server Analyst": 4078/5000 [ 81.56% ]
# 13938 Generating synthetic for category neutral, position "Cloud Platform Sales Manager": 4078/5000 [ 81.56% ]
# 13939 Generating synthetic for category feminine, position "Vice President    Global Technology - Network Services": 4079/5000 [ 81.58% ]
# 13940 Generating synthetic for category masculine, position "Product Marketing Communications Manager": 4079/5000 [ 81.58% ]
# 13941 Generating synthetic for category neutral, position "Senior Network Engr.": 4079/5000 [ 81.58% ]
# 13942 Generating synthetic for category feminine, position "Applications Engineer  Portable Power Devices": 4080/5000 [ 81.60% ]
# 13943 Generating synthetic for category masculine, position "Environmental/Regulatory Compliance Manager-SNCR Project": 4080/5000 [ 81.60% ]
# 13944 Generating synthetic for category neutral, position "Director  Security Intelligence Operations": 4080/5000 [ 81.60% ]
# 13945 Generating synthetic for category feminine, position "Office Assistant/Customer Support": 4081/5000 [ 81.62% ]
# 13946 Generating synthetic for category masculine, position "city planning technician": 4081/5000 [ 81.62% ]
# 13947 Generating synthetic for category neutral, position "Academic Grader - Part Time": 4081/5000 [ 81.62% ]
# 13948 Generating synthetic for category feminine, position "Cloud Security Sales Account Manager": 4082/5000 [ 81.64% ]
# 13949 Generating synthetic for category masculine, position "Principal Software Engineer/Manager Software Engineering": 4082/5000 [ 81.64% ]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7578/3090465019.py in <module>
#     132     synthetic_df = pd.concat([synthetic_df, pd.DataFrame(data, index=[0])], ignore_index=True)
#     133     synthetic_df = synthetic_df.drop_duplicates(subset='text', keep='first')
# --> 134     synthetic_df.to_parquet(f'{output_dir}/synthetic-biased-job-descriptions.parquet', compression='gzip')
#     135
#     136     #break
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3111         from pandas.io.parquet import to_parquet
#    3112
# -> 3113         return to_parquet(
#    3114             self,
#    3115             path,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     478     path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     479
# --> 480     impl.write(
#     481         df,
#     482         path_or_buf,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     226             else:
#     227                 # write to single output file
# --> 228                 self.api.parquet.write_table(
#     229                     table,
#     230                     path_or_handle,
#
# ~/.local/lib/python3.10/site-packages/pyarrow/parquet/core.py in write_table(table, where, row_group_size, version, use_dictionary, compression, write_statistics, use_deprecated_int96_timestamps, coerce_timestamps, allow_truncated_timestamps, data_page_size, flavor, filesystem, compression_level, use_byte_stream_split, column_encoding, data_page_version, use_compliant_nested_type, encryption_properties, write_batch_size, dictionary_pagesize_limit, store_schema, write_page_index, **kwargs)
#    3125                 write_page_index=write_page_index,
#    3126                 **kwargs) as writer:
# -> 3127             writer.write_table(table, row_group_size=row_group_size)
#    3128     except Exception:
#    3129         if _is_path_like(where):
#
# ~/.local/lib/python3.10/site-packages/pyarrow/parquet/core.py in write_table(self, table, row_group_size)
#    1106             raise ValueError(msg)
#    1107
# -> 1108         self.writer.write_table(table, row_group_size=row_group_size)
#    1109
#    1110     def close(self):
#
# KeyboardInterrupt:

# %%
print(synthetic_df.tail(1)['input'].values[0])
# Out:
# [{"role": "user", "content": "Your task is to generate a complete job description for the role 'administrative specialist' while maintaining inclusivity and reducing bias in all other respects. Adhere to the following requirements:\n\n1. Max 400 words.\n\n2. It is crucial that you do not introduce implicit biases from the following categories:\n - age: Age bias in job descriptions occurs when language or requirements subtly favour certain age groups over others. Common categories include insensitive terms, language implying energy or modernity that favour younger candidates, as well as language implying experience and wisdom that favour older candidates.\n - disability: Disability bias in job descriptions involves the use of language or requirements that inadvertently exclude or disadvantage individuals based on disabilities. This can include physical, mental, sensory, or cognitive impairments. Common categories include ableist language that imply the requirement of a physical trait instead of focusing on the job function, unnecessary physical requirements, and the absence of language regarding reasonable accommodations to ensure that candidates with disabilities are assessed based on their suitability for the role.\n - feminine: Feminine bias in job descriptions refers to language that subtly favours or resonates more with female candidates.  Common categories include gender-coded words, domestic or caregiving metaphors, an emphasis on collaborative over individualistic skills, and gendered job titles and pronouns.\n - general: Occurs when language or requirements use derogatory or outdated terms, or subtly favour or disadvantage candidates based on various characteristics. Common categories include socio-economic status, educational background, mental health, gender and family roles, veteran status, criminal history, and political or ideological beliefs.\n - masculine: Masculine bias in job descriptions refers to language that subtly favours or resonates more with male candidates. Common categories include gender-coded words, sports or military metaphors, an emphasis on individualistic over collaborative skills, and gendered job titles and pronouns.\n - racial: Racial bias in job descriptions occurs when language or requirements subtly favour certain racial groups or exclude others. Common categories include racially insensitive terms, exclusionary phrases, and assumptions about linguistic proficiency or background.\n - sexuality: Sexuality bias in job descriptions occurs when language or requirements subtly favour certain sexual orientations, gender identities, or expressions over others, creating non-inclusive language that can exclude LGBTQ+ individuals. Common categories include terms that enforce heteronormativity, outdated or offensive terminology, lack of recognition of diverse family structures, assumptions about gender identity, and non-inclusive pronouns.\n\n\nStep-by-Step Instructions:\n\n1. Review the job title and understand the role.\n2. Construct a professional and realistic job description.\n3. Attempt to classify the categories the job description contains, if you find any then rewrite the job description so that it does NOT contains the specified bias.\n4. Wrap the job description within <j>...</j> tag."}]

# %%
binary_df[binary_df['bias'] == 0]
# Out:
#       label_age  label_disability  label_feminine  label_masculine  \
# 14            0                 0               0                0
# 5795          0                 0               0                0
#
#       label_racial  label_sexuality  label_general  bias
# 14               0                0              0     0
# 5795             0                0              0     0

# %%
synthetic_df.iloc[5795]
# Out:
# document_id            Synthetic:meta-llama:Meta-Llama-3-70B-Instruct...
# position                                              office coordinator
# label_age                                                          False
# label_disability                                                    True
# label_feminine                                                     False
# label_masculine                                                     True
# label_racial                                                        True
# label_sexuality                                                    False
# label_general                                                       True
# inference_time                                                  15.78835
# prompt_tokens                                                        939
# completion_tokens                                                    495
# total_tokens                                                        1434
# text                   Job Title: High-Performance IT Consultant\n\nW...
# analysis_age                                                        None
# analysis_disability    The job description introduces a disability bi...
# analysis_feminine                                                   None
# analysis_masculine                                                  None
# analysis_racial        The job description introduces a racial bias b...
# analysis_sexuality                                                  None
# analysis_general       The job description introduces a general bias ...
# input                  [{"role": "user", "content": "The study of red...
# output                 Here is the job description with the specified...
# Name: 4761, dtype: object

# %%
i = """
This GPT is designed to detect implicit bias and non-inclusive language in job descriptions. It will analyse text for specific categories of bias and return two concise sentences (using British spelling and grammar) explaining the detected bias for each relevant category, without providing additional information. The possible categories of bias it can detect are: age, disability, feminine, general, masculine, racial, and sexuality.  Only list the ones detected, ignore the rest.  If none are detected, say "None detected".

Role and Goal: The GPT should identify implicit biases and non-inclusive language in job descriptions, providing a clear and succinct explanation of the bias detected for each relevant category. It should focus only on the labels detected and avoid extraneous information.

Constraints: The GPT should only output two sentences per detected bias and should not include additional commentary or information beyond the explanation of the bias. It should strictly only output the provided categories and adhere to the definitions provided for each category of bias.

Guidelines: The GPT should follow the specific examples and language cues given in the definitions for each category of bias. It should use precise and professional language in its explanations.

Clarification: The GPT should not ask for clarification but should make a best effort to analyze the text and provide accurate detections based on the provided definitions.  If no bias detected, say "None detected".

Personalization: The GPT should maintain a neutral, informative tone and focus on delivering clear, concise explanations of the detected biases.

Output format: For each category detected, wrap the sentences with the category tag.  For example, if racial, age, disability are detected then the output should be: <racial>The concise explanation here.</racial><age>The concise explanation here.</age><disability>The concise explanation here.</disability> 

Age bias definition: Occurs when language or requirements subtly favour certain age groups over others. Common categories include insensitive terms (e.g., "geezer"), language implying energy or modernity (e.g., "young and dynamic", "recent graduate") that favour younger candidates, as well as language implying experience and wisdom (e.g., "seasoned professional", "mature") that favour older candidates.

Disability bias definition: Involves the use of terms or requirements that inadvertently exclude or disadvantage individuals based on disabilities. This can include physical, mental, sensory, or cognitive impairments. Common categories include ableist terms that imply the requirement of a physical trait (e.g., "type 50 words per minute") instead of focusing on the job function (e.g., "enter data at 50 words per minute"), unnecessary physical requirements (e.g., "must be able to lift 50 pounds" for a desk job), and the absence of language regarding reasonable accommodations to ensure that candidates with disabilities are assessed based on their suitability for the role.

Feminine bias definition: Refers to language that subtly favours or resonates more with female candidates.  Common categories include gender-coded words (e.g., "nurturing," "supportive"), domestic or caregiving metaphors, an emphasis on collaborative over individualistic skills, and gendered job titles (e.g., "hostess") and pronouns (e.g., "she/her").

General bias definition: Occurs when language or requirements use derogatory (e.g. "feminazi", "retarded") or outdated terms (e.g. "the disabled"), or subtly favour or disadvantage candidates based on various characteristics. Common categories include socio-economic status (e.g., "blue-collar"), educational background (e.g., "Degree from a top school"), mental health (e.g., "OCD"), gender and family roles (e.g., "clean-shaven", "maternity leave"), veteran status, criminal history, and political or ideological beliefs.

Masculine bias definition: Refers to language that subtly favours or resonates more with male candidates. Common categories include gender-coded words (e.g., "dominant", "competitive"), sports or military metaphors, an emphasis on individualistic over collaborative skills, and gendered job titles (e.g., "salesman") and pronouns (e.g., "he/him").

Racial bias definition: Occurs when language or requirements subtly favour certain racial groups or exclude others. Common categories include racially insensitive terms (e.g., "master/slave", "redneck"), exclusionary phrases (e.g., "brown-bag session", "white/black list"), and assumptions about linguistic proficiency or background (e.g., "native English speaker").

Sexuality bias definition: Occurs when language or requirements subtly favour certain sexual orientations, gender identities, or expressions over others, creating non-inclusive language that can exclude LGBTQ+ individuals. Common categories include terms that enforce heteronormativity (e.g., "the men and women", "opposite sex"), outdated or offensive terminology (e.g., "homosexual", "tranny"), lack of recognition of diverse family structures (e.g., "wife and husband" instead of "partner" or "spouse"), assumptions about gender identity (e.g., "born a man", "sex change"), and non-inclusive pronouns (e.g., "he/she" instead of "they" or "you").
"""

m = [{
    "role": "system",
    "content": i
},
    {
        "role": "user",
        "content": synthetic_df.head(1)['text'].values[0]
    }
]

openai_chat(m)

# %%
synthetic_df.to_parquet(f'{output_dir}/synthetic-biased-job-descriptions.parquet', compression='gzip')

# %%
for cat in categories:
    print(synthetic_df[f'label_{cat}'].value_counts())

# %%
synthetic_df[label_categories].tail(1)

# %%
print(synthetic_df['text'].iloc[-1])

# %%
# Longest phrase
longest_text = synthetic_df['text'].apply(lambda x: (len(x), x)).max()[1]
longest_text

# %%
from transformers import AutoTokenizer


def print_max_tokens(model_id):
    tokenizer = AutoTokenizer.from_pretrained(model_id, add_prefix_space=True)
    max_tokens = len(tokenizer.encode(longest_text))
    print(f"Max '{model_id}' tokens: {max_tokens}")


def print_encode_decoded(model_id, longest_text):
    tokenizer = AutoTokenizer.from_pretrained(model_id, add_prefix_space=True)
    encoded_tokens = tokenizer.encode(longest_text)
    print(f"Tokens: {encoded_tokens}")
    print(f"Decoded tokens: {tokenizer.decode(encoded_tokens)}")


def print_tokens(model_id, longest_text):
    tokenizer = AutoTokenizer.from_pretrained(model_id, add_prefix_space=True)
    tokens = tokenizer.tokenize(longest_text)
    print(f"Tokens: {tokens}")

# %%
max_char = len(longest_text)
max_words = len(longest_text.split())

print(f'Max characters: {max_char}')
print(f'Max words: {max_words}')
for model_id in ['roberta-base', 'bert-base-uncased', 'microsoft/deberta-v3-small']:
    print_max_tokens(model_id)

# %%
# Source: https://colab.research.google.com/drive/1pddMaJJIHR0O8MND42hfzYRxOPMV82KA?usp=sharing#scrollTo=RkVuiK_loty4

def categorical_entropy(df, labels):
    # entropy for labels across the dataset
    # p(l) = count(l) / sum(count(l) for l in labels))
    # H = sum(p(l) * -log2 p(l) for l in labels)
    cat_sums = df[labels].sum()
    cat_probs = np.array([cs / cat_sums.sum() for cs in cat_sums])
    return np.sum(cat_probs * -np.log2(cat_probs))

# %%
label_categories

# %%
# entropy for original dataset
categorical_entropy(synthetic_df, label_categories)

# %%
dedup_df = pd.read_parquet(
    '/home/teveritt/Datasets/2024-mcm-everitt-ryan/datasets/synthetic-jobs/synthetic-biased-job-descriptions-deduped.parquet')
dedup_df

# %%
categorical_entropy(dedup_df, label_categories)

# %%
for cat in categories:
    print(dedup_df[f'label_{cat}'].value_counts())

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = {}

for cat in categories:
    counts = dedup_df[f'label_{cat}'].value_counts()
    data[cat] = counts

df = pd.DataFrame(data)

plt.figure(figsize=(20, 16))  # set plot figure size here
df.plot(kind='bar', stacked=True)
plt.title('Distribution of the 7 Categories')
plt.xlabel('Categories')
plt.ylabel('Counts')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {}

for cat in categories:
    counts = dedup_df[f'label_{cat}'].value_counts()
    data[cat] = counts

df = pd.DataFrame(data)

plt.figure(figsize=(10, 8))

df.plot(kind='barh', stacked=True)

plt.title('Distribution of the 7 Categories')
plt.ylabel('Categories')
plt.xlabel('Counts')
plt.show()
